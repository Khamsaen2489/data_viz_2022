# %% [markdown]
# <a href="https://colab.research.google.com/github/Khamsaen2489/data_viz_2022/blob/main/Group_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

# %%
path = '/content/drive/My Drive/ Data_Group_Project'

# %%
covid_file_path = os.path.join(path,'confirmed-cases.csv') 
print(covid_file_path)
# Out:
# /content/drive/My Drive/ Data_Group_Project/confirmed-cases.csv

# %%
covid_file_path2 = os.path.join(path,'confirmed-cases-since-120864.csv') 
print(covid_file_path2)
# Out:
# /content/drive/My Drive/ Data_Group_Project/confirmed-cases-since-120864.csv

# %%
covid_file_path3 = os.path.join(path,'confirmed-cases-since-271064.csv') 
print(covid_file_path3)
# Out:
# /content/drive/My Drive/ Data_Group_Project/confirmed-cases-since-271064.csv

# %%
covid_file_path4 = os.path.join(path,'confirmed-cases-since-280265.csv') 
print(covid_file_path4)
# Out:
# /content/drive/My Drive/ Data_Group_Project/confirmed-cases-since-280265.csv

# %% [markdown]
# ## โหลดข้อมูลชุดที่ 1

# %%
data_covid = pd.read_csv(covid_file_path)
data_covid
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#            No. announce_date Notified date   sex   age Unit nationality  \
# 0            1     12/1/2020           NaN  หญิง  61.0   ปี       China
# 1            2     17/1/2020           NaN  หญิง  74.0   ปี       China
# 2            3     22/1/2020           NaN  หญิง  73.0   ปี    Thailand
# 3            4     22/1/2020           NaN   ชาย  68.0   ปี       China
# 4            5     24/1/2020           NaN  หญิง  66.0   ปี       China
# ...        ...           ...           ...   ...   ...  ...         ...
# 839766  839767     12/8/2021     11/8/2021   ชาย  52.0   ปี         NaN
# 839767  839768     12/8/2021     11/8/2021   ชาย  34.0   ปี    Thailand
# 839768  839769     12/8/2021     11/8/2021   ชาย  31.0   ปี    Thailand
# ...

# %%
data_covida = data_covid.dropna(subset=['province_of_onset']).reset_index(drop=True)  #Check Missing Value ของ Data_covida
data_covida
# Out:
#            No. announce_date Notified date   sex   age Unit nationality  \
# 0            1     12/1/2020           NaN  หญิง  61.0   ปี       China
# 1            2     17/1/2020           NaN  หญิง  74.0   ปี       China
# 2            3     22/1/2020           NaN  หญิง  73.0   ปี    Thailand
# 3            4     22/1/2020           NaN   ชาย  68.0   ปี       China
# 4            5     24/1/2020           NaN  หญิง  66.0   ปี       China
# ...        ...           ...           ...   ...   ...  ...         ...
# 740732  839767     12/8/2021     11/8/2021   ชาย  52.0   ปี         NaN
# 740733  839768     12/8/2021     11/8/2021   ชาย  34.0   ปี    Thailand
# 740734  839769     12/8/2021     11/8/2021   ชาย  31.0   ปี    Thailand
# 740735  839770     12/8/2021     11/8/2021   ชาย  83.0   ปี    Thailand
# 740736  839771     12/8/2021     11/8/2021   ชาย  47.0   ปี    Thailand
#
#        province_of_isolation                              risk  \
# ...

# %% [markdown]
# ## โหลดข้อมูลชุดที่ 2

# %%
data_covid2 = pd.read_csv(covid_file_path2)
data_covid2
# Out:
#              No. announce_date Notified date   sex   age Unit nationality  \
# 0         816990     12/8/2021     11/8/2021   ชาย   7.0   ปี    Thailand
# 1         816991     12/8/2021     11/8/2021   ชาย   1.0   ปี    Thailand
# 2         816992     12/8/2021     11/8/2021   ชาย  35.0   ปี    Thailand
# 3         816993     12/8/2021     11/8/2021  หญิง  33.0   ปี    Thailand
# 4         816994     12/8/2021     11/8/2021  หญิง  14.0   ปี    Thailand
# ...          ...           ...           ...   ...   ...  ...         ...
# 1042163  1859153    25/10/2021    24/10/2021   ชาย  45.0   ปี         NaN
# 1042164  1859154    25/10/2021    24/10/2021   ชาย  31.0   ปี         NaN
# 1042165  1859155    25/10/2021    24/10/2021   ชาย  31.0   ปี         NaN
# 1042166  1859156    25/10/2021    24/10/2021   ชาย  24.0   ปี         NaN
# 1042167  1859157    25/10/2021    24/10/2021   ชาย  25.0   ปี         NaN
#
#         province_of_isolation                                         risk  \
# ...

# %%
data_covidaa = data_covid2.dropna(subset=['province_of_onset']).reset_index(drop=True)  #Check Missing Value ของ Data_covida
data_covidaa
# Out:
#             No. announce_date Notified date   sex   age Unit nationality  \
# 0        817239     12/8/2021     11/8/2021   ชาย  48.0   ปี    Thailand
# 1        817240     12/8/2021     11/8/2021  หญิง  19.0   ปี    Thailand
# 2        817241     12/8/2021     11/8/2021  หญิง  37.0   ปี    Thailand
# 3        817242     12/8/2021     11/8/2021   ชาย  46.0   ปี    Thailand
# 4        817243     12/8/2021     11/8/2021   ชาย  60.0   ปี    Thailand
# ...         ...           ...           ...   ...   ...  ...         ...
# 897589  1858952    25/10/2021    24/10/2021   ชาย  67.0   ปี    Thailand
# 897590  1858953    25/10/2021    24/10/2021  หญิง  39.0   ปี    Thailand
# 897591  1858954    25/10/2021    24/10/2021   ชาย  80.0   ปี    Thailand
# 897592  1858955    25/10/2021    24/10/2021  หญิง  67.0   ปี    Thailand
# 897593  1858956    25/10/2021    24/10/2021  หญิง  53.0   ปี    Thailand
#
#        province_of_isolation                                         risk  \
# ...

# %% [markdown]
# ## โหลดข้อมูลชุดที่ 3

# %%
data_covid3 = pd.read_csv(covid_file_path3)
data_covid3
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#              No. announce_date Notified date   sex   age Unit nationality  \
# 0        1859158    26/10/2021    25/10/2021   ชาย  20.0   ปี    Thailand
# 1        1859159    26/10/2021    25/10/2021  หญิง  42.0   ปี    Thailand
# 2        1859160    26/10/2021    25/10/2021  หญิง  33.0   ปี    Thailand
# 3        1859161    26/10/2021    25/10/2021  หญิง  52.0   ปี    Thailand
# 4        1859162    26/10/2021    25/10/2021  หญิง  84.0   ปี    Thailand
# ...          ...           ...           ...   ...   ...  ...         ...
# 1010454  2869612     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# 1010455  2869613     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# 1010456  2869614     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# ...

# %%
data_covidaaa = data_covid3.dropna(subset=['province_of_onset']).reset_index(drop=True)  #Check Missing Value ของ Data_covida
data_covidaaa
# Out:
#             No. announce_date Notified date   sex   age Unit nationality  \
# 0       1859158    26/10/2021    25/10/2021   ชาย  20.0   ปี    Thailand
# 1       1859159    26/10/2021    25/10/2021  หญิง  42.0   ปี    Thailand
# 2       1859160    26/10/2021    25/10/2021  หญิง  33.0   ปี    Thailand
# 3       1859161    26/10/2021    25/10/2021  หญิง  52.0   ปี    Thailand
# 4       1859162    26/10/2021    25/10/2021  หญิง  84.0   ปี    Thailand
# ...         ...           ...           ...   ...   ...  ...         ...
# 899168  2869540     27/2/2022     26/2/2022  หญิง   NaN  NaN    Thailand
# 899169  2869541     27/2/2022     26/2/2022   ชาย   NaN  NaN    Thailand
# 899170  2869542     27/2/2022     26/2/2022   ชาย   NaN  NaN    Thailand
# 899171  2869543     27/2/2022     26/2/2022  หญิง   NaN  NaN    Thailand
# 899172  2869544     27/2/2022     26/2/2022  หญิง   NaN  NaN    Thailand
#
#        province_of_isolation                                           risk  \
# ...

# %% [markdown]
# ## โหลดข้อมูลชุดที่ 4

# %%
data_covid4 = pd.read_csv(covid_file_path4)
data_covid4
# Out:
#             No. announce_date Notified date   sex   age Unit nationality  \
# 0       2869617     28/2/2022     27/2/2022   ชาย  41.0   ปี    Thailand
# 1       2869618     28/2/2022     27/2/2022  หญิง  45.0   ปี    Thailand
# 2       2869619     28/2/2022     27/2/2022  หญิง  40.0   ปี    Thailand
# 3       2869620     28/2/2022     27/2/2022   ชาย  44.0   ปี    Thailand
# 4       2869621     28/2/2022     27/2/2022   ชาย  11.0   ปี    Thailand
# ...         ...           ...           ...   ...   ...  ...         ...
# 433548  3303165     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433549  3303166     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433550  3303167     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433551  3303168     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433552  3303169     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
#
#        province_of_isolation                                         risk  \
# ...

# %%
data_covidaaaa = data_covid4.dropna(subset=['province_of_onset']).reset_index(drop=True)  #Check Missing Value ของ Data_covida
data_covidaaaa
# Out:
#             No. announce_date Notified date   sex   age Unit nationality  \
# 0       2869617     28/2/2022     27/2/2022   ชาย  41.0   ปี    Thailand
# 1       2869618     28/2/2022     27/2/2022  หญิง  45.0   ปี    Thailand
# 2       2869619     28/2/2022     27/2/2022  หญิง  40.0   ปี    Thailand
# 3       2869620     28/2/2022     27/2/2022   ชาย  44.0   ปี    Thailand
# 4       2869621     28/2/2022     27/2/2022   ชาย  11.0   ปี    Thailand
# ...         ...           ...           ...   ...   ...  ...         ...
# 388296  3303061     18/3/2022     17/3/2022   NaN  11.0   ปี         NaN
# 388297  3303063     18/3/2022     17/3/2022   NaN  21.0   ปี         NaN
# 388298  3303064     18/3/2022     17/3/2022   NaN  22.0   ปี         NaN
# 388299  3303065     18/3/2022     17/3/2022   NaN  25.0   ปี         NaN
# 388300  3303066     18/3/2022     17/3/2022   NaN  64.0   ปี         NaN
#
#        province_of_isolation                                         risk  \
# ...

# %% [markdown]
# ## เชื่อมข้อมูลทั้ง 4 ชุดเข้าด้วยกัน

# %%
data_covid_new = pd.concat([data_covid, data_covid2, data_covid3, data_covid4])
data_covid_new
# Out:
#             No. announce_date Notified date   sex   age Unit nationality  \
# 0             1     12/1/2020           NaN  หญิง  61.0   ปี       China
# 1             2     17/1/2020           NaN  หญิง  74.0   ปี       China
# 2             3     22/1/2020           NaN  หญิง  73.0   ปี    Thailand
# 3             4     22/1/2020           NaN   ชาย  68.0   ปี       China
# 4             5     24/1/2020           NaN  หญิง  66.0   ปี       China
# ...         ...           ...           ...   ...   ...  ...         ...
# 433548  3303165     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433549  3303166     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433550  3303167     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433551  3303168     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433552  3303169     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
#
#        province_of_isolation                              risk  \
# ...

# %%
data_covid_new.shape
# Out:
# (3325951, 12)

# %%
data_covid_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3325951 entries, 0 to 433552
# Data columns (total 12 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   No.                    int64
#  1   announce_date          object
#  2   Notified date          object
#  3   sex                    object
#  4   age                    object
#  5   Unit                   object
#  6   nationality            object
#  7   province_of_isolation  object
#  8   risk                   object
#  9   province_of_onset      object
#  10  district_of_onset      object
#  11  Unnamed: 11            float64
# dtypes: float64(1), int64(1), object(10)
# memory usage: 329.9+ MB

# %% [markdown]
# ## Check Missing Value

# %%
data_covid_new.isnull()
# Out:
#           No.  announce_date  Notified date    sex    age   Unit  nationality  \
# 0       False          False           True  False  False  False        False
# 1       False          False           True  False  False  False        False
# 2       False          False           True  False  False  False        False
# 3       False          False           True  False  False  False        False
# 4       False          False           True  False  False  False        False
# ...       ...            ...            ...    ...    ...    ...          ...
# 433548  False          False          False  False   True   True         True
# 433549  False          False          False  False   True   True         True
# 433550  False          False          False  False   True   True         True
# 433551  False          False          False  False   True   True         True
# 433552  False          False          False  False   True   True         True
#
# ...
