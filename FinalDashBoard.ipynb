# %% [markdown]
# <a href="https://colab.research.google.com/github/Khamsaen2489/data_viz_2022/blob/main/FinalDashBoard.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ❗**Final Exam: งานกลุ่ม Final ที่อาจารย์สุ่มให้**:
#
#
# 1.  ให้นักศึกษาสร้าง Dashboard แสดงรายงานเกี่ยวกับข้อมูลการตรวจโรค(ov) จาก ไฟล์  alldb.csv และ hospital_list.xlsx
# 2.   โดยข้อมูลหลักจะอยู่ใน ตาราง alldb.csv (ข้อมูลที่สมบูรณ์ที่สามารถนำมาใช้งานได้ต้องมีค่าใน column ต่อไปนี้ดังนี้
#
#
# * user เป็นตัวเลข 5 หลัก (ตัวเลขเท่านั้น)
# * RowKey เป็น String
# * date เป็น YYYY-MM-DD
# * phone เป็น String
# * site เป็นตัวเลข 5 หลัก (ตัวเลขเท่านั้น)
# * time เป็น hh-mm-ss
# * urine มีค่า String
# * ov เป็นตัวเลข มีค่าตั้งแต่ 0-4 (0 คือไม่พบโรค 1-4 คือพบโรคที่ระดับความรุนแรงต่างๆ)
# * PartitionKey เป็นตัวเลข 5 หลัก (ตัวเลขเท่านั้น))
#
# 3. ไฟล์ alldb.csv และ hospital_list.xlsx สามารถถูกเชื่อมโยงกันโดย site ในไฟล์ alldb.csv คือ hcode ในไฟล์ hospital_list.xlsx
#
# โดยข้อมูลสำคัญที่ต้องแสดงคือ
#
# * จำนวนการตรวจในแต่ละพื้นที่ (จังหวัด-อำเภอ ในไฟล์ hospital_list.xlsx) เทียบกับ จำนวนที่พบโรค (column ov ในไฟล์ alldb.csv)
# * ช่วงเวลาที่ตรวจ (date ในไฟล์ alldb.csv)
# * อื่นๆที่นักศึกษาเห็นว่าเป็นประโยชน์ (phone (ชนิดโทรศัพท์ที่ใช้บันทึก), title (คำนำหน้าชื่อ), age (อายุ))
#
# (คิดคะแนนตามกลุ่ม final โดยไฟล์ที่ทุกคนในกลุ่มต้องมีคือไฟล์ data pre-processing และ link ไปที่ Dashboard ที่สร้่างโดยเปิดให้สามารถเข้าไปดูและใช้งานได้)
# ส่งไม่เกิน 23.59 วันจันทร์ที่ 11 เมษายน 2565

# %% [markdown]
# # ✅ link ไปที่ Dashboard
#
# [https://datastudio.google.com/s/vFv5_v4X2GM](https://)

# %% [markdown]
# # 🔗 Import Data

# %%
import pandas as pd #เพื่อใช้ทำงานกับข้อมูลที่เป็นรูปแบบตาราง
import os           #เพื่อจัดการกับไฟล์ และ ตัว path ที่เราจะนำเข้า

# %%
from google.colab import drive # เชื่อมบัญชีกับ google drive
drive.mount('/content/drive') # เช็คว่าเชื่อมติดหรือไม่
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = '/content/drive/My Drive/Final_Dataviz'

# %% [markdown]
# ##Data 1 alldb.csv

# %%
data1_alldb = pd.read_csv(os.path.join(path,'alldb.csv'))
data1_alldb ## แสดงตาราง
# Out:
#        Unnamed: 0           user                                    RowKey  \
# 0               0           test                                       NaN
# 1               1          04857      136FD222-FD9F-4E54-AE1F-7282A276B085
# 2               2            NaN  1E6D3D62-4C8A-4F8E-90D1-0DC5BC2752DF.png
# 3               3  3450101576642      2D331FB0-CBA2-4586-A5B0-CB3CF44DD9FE
# 4               4  3450101576642      45197AF7-7CB4-470C-9ABB-37C092BD6B21
# ...           ...            ...                                       ...
# 40030       40030            NaN      6B5FA20F-190E-4021-8547-C12308024C6C
# 40031       40031            NaN      F48C51C0-A345-40D6-93F4-46213267E1B1
# 40032       40032            NaN      A986BDAA-6D7C-4017-8E62-A3C104E946B9
# 40033       40033            NaN                            bbuogxulur.png
# 40034       40034            NaN                            zttpqogiso.png
#
#       care        date   ov             phone   site      time  \
# ...

# %%
data1_alldb= data1_alldb.rename(columns={'title':'gender'})  #  เปลี่ยนชื่อ คอลัมน์ title เป็น gender
data1_alldb ## แสดงตาราง
# Out:
#        Unnamed: 0           user                                    RowKey  \
# 0               0           test                                       NaN
# 1               1          04857      136FD222-FD9F-4E54-AE1F-7282A276B085
# 2               2            NaN  1E6D3D62-4C8A-4F8E-90D1-0DC5BC2752DF.png
# 3               3  3450101576642      2D331FB0-CBA2-4586-A5B0-CB3CF44DD9FE
# 4               4  3450101576642      45197AF7-7CB4-470C-9ABB-37C092BD6B21
# ...           ...            ...                                       ...
# 40030       40030            NaN      6B5FA20F-190E-4021-8547-C12308024C6C
# 40031       40031            NaN      F48C51C0-A345-40D6-93F4-46213267E1B1
# 40032       40032            NaN      A986BDAA-6D7C-4017-8E62-A3C104E946B9
# 40033       40033            NaN                            bbuogxulur.png
# 40034       40034            NaN                            zttpqogiso.png
#
#       care        date   ov             phone   site      time  \
# ...

# %% [markdown]
# # ▶ user เป็นตัวเลข 5 หลัก (ตัวเลขเท่านั้น)

# %%
data1_alldb = data1_alldb[(data1_alldb['user'].astype(str).str.isdigit()) & (data1_alldb['user'].str.len() == 5)]      # เลือกมาเฉพาะ คอลัมน์ user ที่เป็นตัวเลข & มีตัวเลข เท่ากับ 5 ตัว
data1_alldb ## แสดงตาราง
# Out:
#        Unnamed: 0   user                                RowKey care  \
# 1               1  04857  136FD222-FD9F-4E54-AE1F-7282A276B085  NaN
# 5               5  08777  472EED3E-E2A7-4551-9249-D87747C68AFD  NaN
# 7               7  04857  73E96EE6-7660-4204-9914-92112603C514  NaN
# 11             11  08777  C23A546B-EB6E-4DB4-93FA-2F9A7A85AEE9  NaN
# 12             12  11111  C42C6F97-4388-4C03-A0AB-84F21FAED2C2  NaN
# ...           ...    ...                                   ...  ...
# 39813       39813  99999                        lnlohgqckf.png  NaN
# 39814       39814  99999                        vkdocpmjiv.png  NaN
# 39815       39815  99999                        vrvyfnvayq.png  NaN
# 39816       39816  99999                        zuhbtvyrce.png  NaN
# 40017       40017  12345                        zgvicawbkg.png  NaN
#
#              date   ov             phone   site      time  \
# 1      2022-02-24  NaN        iPhone10,4  05310  10:50:32
# ...

# %%
set(data1_alldb['user'])
# Out:
# {'32622',
#  '11055',
#  '65656',
#  '00152',
#  '29094',
#  '16904',
#  '80382',
#  '81621',
#  '89329',
#  '57066',
#  '07644',
#  '33664',
#  '03359',
#  '16604',
#  '32468',
#  '33553',
#  '43257',
#  '96417',
#  '88973',
#  '92120',
#  '71152',
#  '28291',
#  '64385',
#  '05590',
#  '59361',
#  '61087',
#  '30660',
#  '94392',
#  '81570',
#  '36692',
#  '29051',
#  '25659',
#  '04193',
#  '81409',
#  '46643',
#  '00215',
#  '78251',
#  '84540',
#  '00230',
#  '00032',
#  '51175',
#  '18318',
#  '67778',
#  '36001',
#  '87029',
#  '97860',
#  '77384',
#  '39965',
#  '74369',
#  '00252',
#  '00047',
#  '82822',
#  '72486',
#  '21432',
#  '75838',
#  '00157',
#  '37127',
#  '53751',
#  '05091',
#  '31619',
#  '22119',
#  '63312',
#  '18181',
#  '28743',
#  '89470',
#  '71998',
#  '64817',
#  '26574',
#  '63039',
#  '86981',
#  '14455',
#  '24032',
#  '06924',
#  '59051',
#  '87181',
#  '16630',
#  '00076',
#  '00159',
#  '45752',
#  '39593',
#  '50276',
#  '31011',
#  '18513',
# ...

# %% [markdown]
# # ▶ RowKey เป็น String

# %%
data1_alldb['RowKey']=data1_alldb['RowKey'].astype('string') #เปลี่ยน dtype เป็น  String
data1_alldb ## แสดงตาราง
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#        Unnamed: 0   user                                RowKey care  \
# 1               1  04857  136FD222-FD9F-4E54-AE1F-7282A276B085  NaN
# 5               5  08777  472EED3E-E2A7-4551-9249-D87747C68AFD  NaN
# 7               7  04857  73E96EE6-7660-4204-9914-92112603C514  NaN
# 11             11  08777  C23A546B-EB6E-4DB4-93FA-2F9A7A85AEE9  NaN
# 12             12  11111  C42C6F97-4388-4C03-A0AB-84F21FAED2C2  NaN
# ...           ...    ...                                   ...  ...
# 39813       39813  99999                        lnlohgqckf.png  NaN
# ...

# %%
print(data1_alldb.dtypes)  #พบว่า RowKey เป็น String
# Out:
# Unnamed: 0       int64
# user            object
# RowKey          string
# care            object
# date            object
# ov              object
# phone           object
# site            object
# time            object
# urine           object
# pid             object
# PartitionKey    object
# gender          object
# age             object
# dtype: object

# %% [markdown]
# # ▶ date เป็น YYYY-MM-DD

# %%
data1_alldb['date'] = pd.to_datetime(data1_alldb ['date'],format='%Y/%m/%d') #เปลี่ยนรูปแบบของ วันเดือนปี 
data1_alldb ## แสดงตาราง
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#        Unnamed: 0   user                                RowKey care  \
# 1               1  04857  136FD222-FD9F-4E54-AE1F-7282A276B085  NaN
# 5               5  08777  472EED3E-E2A7-4551-9249-D87747C68AFD  NaN
# 7               7  04857  73E96EE6-7660-4204-9914-92112603C514  NaN
# 11             11  08777  C23A546B-EB6E-4DB4-93FA-2F9A7A85AEE9  NaN
# 12             12  11111  C42C6F97-4388-4C03-A0AB-84F21FAED2C2  NaN
# ...           ...    ...                                   ...  ...
# 39813       39813  99999                        lnlohgqckf.png  NaN
# ...

# %%
data1_alldb[['date']] = data1_alldb[['date']].fillna('ไม่ระบุ') #แทน 'ไม่ระบุ' ในค่าว่าง
data1_alldb ## แสดงตาราง
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
#        Unnamed: 0   user                                RowKey care  \
# 1               1  04857  136FD222-FD9F-4E54-AE1F-7282A276B085  NaN
# 5               5  08777  472EED3E-E2A7-4551-9249-D87747C68AFD  NaN
# 7               7  04857  73E96EE6-7660-4204-9914-92112603C514  NaN
# 11             11  08777  C23A546B-EB6E-4DB4-93FA-2F9A7A85AEE9  NaN
# 12             12  11111  C42C6F97-4388-4C03-A0AB-84F21FAED2C2  NaN
# ...           ...    ...                                   ...  ...
# 39813       39813  99999                        lnlohgqckf.png  NaN
# ...

# %% [markdown]
# # ▶ phone เป็น String

# %%
data1_alldb['phone']=data1_alldb['phone'].astype('string') #เปลี่ยน dtype เป็น  String
data1_alldb ## แสดงตาราง
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#        Unnamed: 0   user                                RowKey care  \
# 1               1  04857  136FD222-FD9F-4E54-AE1F-7282A276B085  NaN
# 5               5  08777  472EED3E-E2A7-4551-9249-D87747C68AFD  NaN
# 7               7  04857  73E96EE6-7660-4204-9914-92112603C514  NaN
# 11             11  08777  C23A546B-EB6E-4DB4-93FA-2F9A7A85AEE9  NaN
# 12             12  11111  C42C6F97-4388-4C03-A0AB-84F21FAED2C2  NaN
# ...           ...    ...                                   ...  ...
# 39813       39813  99999                        lnlohgqckf.png  NaN
# ...

# %%
print(data1_alldb.dtypes)  #พบว่า phone เป็น String
# Out:
# Unnamed: 0       int64
# user            object
# RowKey          string
# care            object
# date            object
# ov              object
# phone           string
# site            object
# time            object
# urine           object
# pid             object
# PartitionKey    object
# gender          object
# age             object
# dtype: object

# %% [markdown]
# # ▶ site เป็นตัวเลข 5 หลัก (ตัวเลขเท่านั้น)

# %%
data1_alldb= data1_alldb[(data1_alldb['site'].astype(str).str.isdigit()) & (data1_alldb['site'].str.len() == 5)]         # เลือกมาเฉพาะ คอลัมน์ site ที่เป็นตัวเลข & มีตัวเลข เท่ากับ 5 ตัว
data1_alldb ## แสดงตาราง
# Out:
#        Unnamed: 0   user                                RowKey care  \
# 1               1  04857  136FD222-FD9F-4E54-AE1F-7282A276B085  NaN
# 5               5  08777  472EED3E-E2A7-4551-9249-D87747C68AFD  NaN
# 7               7  04857  73E96EE6-7660-4204-9914-92112603C514  NaN
# 11             11  08777  C23A546B-EB6E-4DB4-93FA-2F9A7A85AEE9  NaN
# 12             12  11111  C42C6F97-4388-4C03-A0AB-84F21FAED2C2  NaN
# ...           ...    ...                                   ...  ...
# 39812       39812  99999  F45E78D3-7D89-47A3-8207-C705377E0E0A  NaN
# 39813       39813  99999                        lnlohgqckf.png  NaN
# 39814       39814  99999                        vkdocpmjiv.png  NaN
# 39815       39815  99999                        vrvyfnvayq.png  NaN
# 39816       39816  99999                        zuhbtvyrce.png  NaN
#
#                       date   ov             phone   site      time  \
# 1      2022-02-24 00:00:00  NaN        iPhone10,4  05310  10:50:32
# ...

# %%
set(data1_alldb['site'])
# Out:
# {'00004',
#  '00006',
#  '00007',
#  '00008',
#  '00012',
#  '00016',
#  '00017',
#  '00018',
#  '00027',
#  '00028',
#  '00040',
#  '00052',
#  '00055',
#  '00061',
#  '00069',
#  '00070',
#  '00071',
#  '00081',
#  '00082',
#  '00090',
#  '00094',
#  '00096',
#  '00108',
#  '00109',
#  '00115',
#  '00120',
#  '00122',
#  '00127',
#  '00163',
#  '00164',
#  '00165',
#  '00166',
#  '00169',
#  '00170',
#  '00171',
#  '00173',
#  '00174',
#  '00176',
#  '00177',
#  '00178',
#  '00179',
#  '00180',
#  '00182',
#  '00185',
#  '00186',
#  '00187',
#  '00189',
#  '00190',
#  '00191',
#  '00192',
#  '00193',
#  '00194',
#  '00195',
#  '00196',
#  '00197',
#  '00198',
#  '00200',
#  '00202',
#  '00204',
#  '00205',
#  '00206',
#  '00207',
#  '00209',
#  '00213',
#  '00214',
#  '00217',
#  '00218',
#  '00219',
#  '00229',
#  '00232',
#  '00235',
#  '00240',
#  '00247',
#  '00266',
#  '00271',
#  '00279',
#  '00323',
#  '00331',
#  '00333',
#  '00346',
#  '00348',
#  '00381',
#  '00382',
# ...

# %% [markdown]
# # ▶ time เป็น hh-mm-ss

# %%
data1_alldb['time'] = pd.to_datetime(data1_alldb['time'],format='%H:%M%:%S',errors='ignore')  #เปลี่ยนรูปแบบของ time 
data1_alldb ## แสดงตาราง
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#        Unnamed: 0   user                                RowKey care  \
# 1               1  04857  136FD222-FD9F-4E54-AE1F-7282A276B085  NaN
# 5               5  08777  472EED3E-E2A7-4551-9249-D87747C68AFD  NaN
# 7               7  04857  73E96EE6-7660-4204-9914-92112603C514  NaN
# 11             11  08777  C23A546B-EB6E-4DB4-93FA-2F9A7A85AEE9  NaN
# 12             12  11111  C42C6F97-4388-4C03-A0AB-84F21FAED2C2  NaN
# ...           ...    ...                                   ...  ...
# 39812       39812  99999  F45E78D3-7D89-47A3-8207-C705377E0E0A  NaN
# ...

# %%
data1_alldb[['time']] = data1_alldb[['time']].fillna('ไม่ระบุ')  #แทน ไม่ระบุ ในค่าว่าง
data1_alldb ## แสดงตาราง
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
#        Unnamed: 0   user                                RowKey care  \
# 1               1  04857  136FD222-FD9F-4E54-AE1F-7282A276B085  NaN
# 5               5  08777  472EED3E-E2A7-4551-9249-D87747C68AFD  NaN
# 7               7  04857  73E96EE6-7660-4204-9914-92112603C514  NaN
# 11             11  08777  C23A546B-EB6E-4DB4-93FA-2F9A7A85AEE9  NaN
# 12             12  11111  C42C6F97-4388-4C03-A0AB-84F21FAED2C2  NaN
# ...           ...    ...                                   ...  ...
# 39812       39812  99999  F45E78D3-7D89-47A3-8207-C705377E0E0A  NaN
# ...

# %% [markdown]
# # ▶ urine มีค่า String

# %%
data1_alldb['urine']=data1_alldb['urine'].astype('string') #เปลี่ยน dtype เป็น  String
data1_alldb ## แสดงตาราง
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#        Unnamed: 0   user                                RowKey care  \
# 1               1  04857  136FD222-FD9F-4E54-AE1F-7282A276B085  NaN
# 5               5  08777  472EED3E-E2A7-4551-9249-D87747C68AFD  NaN
# 7               7  04857  73E96EE6-7660-4204-9914-92112603C514  NaN
# 11             11  08777  C23A546B-EB6E-4DB4-93FA-2F9A7A85AEE9  NaN
# 12             12  11111  C42C6F97-4388-4C03-A0AB-84F21FAED2C2  NaN
# ...           ...    ...                                   ...  ...
# 39812       39812  99999  F45E78D3-7D89-47A3-8207-C705377E0E0A  NaN
# ...

# %%
print(data1_alldb.dtypes) #พบว่า urine  เป็น   string
# Out:
# Unnamed: 0       int64
# user            object
# RowKey          string
# care            object
# date            object
# ov              object
# phone           string
# site            object
# time            object
# urine           string
# pid             object
# PartitionKey    object
# gender          object
# age             object
# dtype: object

# %%
data1_alldb[['urine']] = data1_alldb[['urine']].fillna('ไม่ระบุ')  #แทน ไม่ระบุ ในค่าว่าง
data1_alldb ## แสดงตาราง
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
#        Unnamed: 0   user                                RowKey care  \
# 1               1  04857  136FD222-FD9F-4E54-AE1F-7282A276B085  NaN
# 5               5  08777  472EED3E-E2A7-4551-9249-D87747C68AFD  NaN
# 7               7  04857  73E96EE6-7660-4204-9914-92112603C514  NaN
# 11             11  08777  C23A546B-EB6E-4DB4-93FA-2F9A7A85AEE9  NaN
# 12             12  11111  C42C6F97-4388-4C03-A0AB-84F21FAED2C2  NaN
# ...           ...    ...                                   ...  ...
# 39812       39812  99999  F45E78D3-7D89-47A3-8207-C705377E0E0A  NaN
# ...

# %% [markdown]
# # ▶ ov เป็นตัวเลข มีค่าตั้งแต่ 0-4 (0 คือไม่พบโรค 1-4 คือพบโรคที่ระดับความรุนแรงต่างๆ)

# %%
data1_alldb['ov']
# Out:
# 1        NaN
# 5        NaN
# 7        NaN
# 11       NaN
# 12       NaN
#         ...
# 39812      1
# 39813      0
# 39814      1
# 39815      1
# 39816      1
# Name: ov, Length: 38493, dtype: object

# %%
set(data1_alldb['ov']) #เรียกดูset ของov
# Out:
# {'0', '1', '2', '3', '4', nan, 'ติดเชื้อ +2 '}

# %%
data1_alldb =data1_alldb[data1_alldb['ov']!='ติดเชื้อ +2 ']  #ไม่เอา 'ติดเชื้อ +2 '
data1_alldb ## แสดงตาราง
# Out:
#        Unnamed: 0   user                                RowKey care  \
# 1               1  04857  136FD222-FD9F-4E54-AE1F-7282A276B085  NaN
# 5               5  08777  472EED3E-E2A7-4551-9249-D87747C68AFD  NaN
# 7               7  04857  73E96EE6-7660-4204-9914-92112603C514  NaN
# 11             11  08777  C23A546B-EB6E-4DB4-93FA-2F9A7A85AEE9  NaN
# 12             12  11111  C42C6F97-4388-4C03-A0AB-84F21FAED2C2  NaN
# ...           ...    ...                                   ...  ...
# 39812       39812  99999  F45E78D3-7D89-47A3-8207-C705377E0E0A  NaN
# 39813       39813  99999                        lnlohgqckf.png  NaN
# 39814       39814  99999                        vkdocpmjiv.png  NaN
# 39815       39815  99999                        vrvyfnvayq.png  NaN
# 39816       39816  99999                        zuhbtvyrce.png  NaN
#
#                       date   ov             phone   site      time  \
# 1      2022-02-24 00:00:00  NaN        iPhone10,4  05310  10:50:32
# ...

# %%
data1_alldb[['ov']] = data1_alldb[['ov']].fillna('ไม่ระบุ')  #แทน ไม่ระบุ ในค่าว่าง
data1_alldb ## แสดงตาราง
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
#        Unnamed: 0   user                                RowKey care  \
# 1               1  04857  136FD222-FD9F-4E54-AE1F-7282A276B085  NaN
# 5               5  08777  472EED3E-E2A7-4551-9249-D87747C68AFD  NaN
# 7               7  04857  73E96EE6-7660-4204-9914-92112603C514  NaN
# 11             11  08777  C23A546B-EB6E-4DB4-93FA-2F9A7A85AEE9  NaN
# 12             12  11111  C42C6F97-4388-4C03-A0AB-84F21FAED2C2  NaN
# ...           ...    ...                                   ...  ...
# 39812       39812  99999  F45E78D3-7D89-47A3-8207-C705377E0E0A  NaN
# ...

# %% [markdown]
# # ▶ PartitionKey เป็นตัวเลข 5 หลัก (ตัวเลขเท่านั้น)

# %%
data1_alldb= data1_alldb[(data1_alldb['PartitionKey'].astype(str).str.isdigit()) & (data1_alldb['PartitionKey'].str.len() == 5)]      # เลือกมาเฉพาะ คอลัมน์ PartitionKey ที่เป็นตัวเลข & มีตัวเลข เท่ากับ 5 ตัว
data1_alldb ## แสดงตาราง
# Out:
#        Unnamed: 0   user                                RowKey care  \
# 190           190  06223                        kfpwuaqldj.png  NaN
# 191           191  12015  00859DB9-1BD9-4825-B246-3DC25EFD1924  NaN
# 192           192  91811  1376ACA2-AFA5-4457-967A-D2FCF908E6A5  NaN
# 193           193  95821  1914EE67-CD8F-47EE-A968-2772911AA5DF  NaN
# 194           194  13361  1A219EE7-3647-4D7D-A8C0-AE638E69D889  NaN
# ...           ...    ...                                   ...  ...
# 39812       39812  99999  F45E78D3-7D89-47A3-8207-C705377E0E0A  NaN
# 39813       39813  99999                        lnlohgqckf.png  NaN
# 39814       39814  99999                        vkdocpmjiv.png  NaN
# 39815       39815  99999                        vrvyfnvayq.png  NaN
# 39816       39816  99999                        zuhbtvyrce.png  NaN
#
#                       date ov              phone   site      time  \
# 190    2022-03-23 00:00:00  0  Xiaomi 21081111RG  13777  16:31:45
# ...

# %%
set(data1_alldb['PartitionKey'])
# Out:
# {'01667',
#  '02887',
#  '04717',
#  '01352',
#  '02892',
#  '02456',
#  '01834',
#  '03060',
#  '03309',
#  '02808',
#  '00371',
#  '01504',
#  '10975',
#  '00152',
#  '01738',
#  '00973',
#  '01333',
#  '04033',
#  '02486',
#  '02702',
#  '00818',
#  '01382',
#  '02253',
#  '02190',
#  '01367',
#  '02673',
#  '03983',
#  '10998',
#  '03462',
#  '00430',
#  '10966',
#  '01671',
#  '01292',
#  '11003',
#  '03189',
#  '33664',
#  '04785',
#  '02461',
#  '01736',
#  '00390',
#  '01821',
#  '03359',
#  '08979',
#  '02421',
#  '01620',
#  '02951',
#  '02936',
#  '00383',
#  '02791',
#  '00696',
#  '01451',
#  '02674',
#  '01541',
#  '08958',
#  '04072',
#  '03137',
#  '00747',
#  '00832',
#  '01817',
#  '03128',
#  '02439',
#  '04665',
#  '01868',
#  '06182',
#  '04193',
#  '00988',
#  '00917',
#  '03176',
#  '00541',
#  '01259',
#  '05147',
#  '00215',
#  '00638',
#  '01992',
#  '01808',
#  '00230',
#  '05343',
#  '00851',
#  '00931',
#  '00032',
#  '00457',
#  '02156',
#  '00505',
# ...

# %% [markdown]
# # ▶ อื่นๆที่เห็นว่าเป็นประโยชน์ [gender]

# %%
data1_alldb['gender']
# Out:
# 190         NaN
# 191      นางสาว
# 192         นาง
# 193         นาง
# 194         นาย
#           ...
# 39812       NaN
# 39813       NaN
# 39814       NaN
# 39815       NaN
# 39816       NaN
# Name: gender, Length: 38381, dtype: object

# %%
set(data1_alldb['gender']) #เรียกดูset ของgender
# Out:
# {'  นาง',
#  ' นาง',
#  ' นางสาว',
#  ' นาย',
#  'Mrs',
#  nan,
#  'ชาย',
#  'ด.ช.',
#  'ด.ญ.',
#  'ด.ต.',
#  'น',
#  'น.ส',
#  'น.ส ',
#  'น.ส.',
#  'นส',
#  'นส.',
#  'นส. ',
#  'นาง',
#  'นาง ',
#  'นาง.',
#  'นางl',
#  'นางสาว',
#  'นางสาว ',
#  'นางสาว                   ',
#  'นาน',
#  'นาบ',
#  'นาย',
#  'นาย ',
#  'นาย  ',
#  'นาว',
#  'นาวสาว',
#  'นา่ง',
#  'น่าย',
#  'พจอ.',
#  'พระ',
#  'พระครุ',
#  'พระปลัด',
#  'พลฯ',
#  'ร.ต.',
#  'ร.ต.ต.',
#  'ร.ต.ท.',
#  'ร.ต.อ.',
#  'รต.',
#  'ว่าที่ ร.ต.',
#  'ว่าที่ ร.ท.',
#  'ว่าที่ร้อยตรี',
#  'ส.อ.',
#  'ืนาง',
#  'เด็กชาย',
#  'เด็กหญิง'}

# %%
data1_alldb['gender'].replace({'  นาง':'หญิง',' นาง':'หญิง', ' นางสาว':'หญิง', ' นาย':'ชาย','Mrs':'หญิง', 'ชาย':'ชาย', 'ด.ช.':'ชาย','ด.ญ.':'หญิง','ด.ต.':'ไม่ระบุ','น':'ไม่ระบุ','น.ส':'หญิง','น.ส ':'หญิง','น.ส.':'หญิง',
                                 'นส':'หญิง', 'นส.':'หญิง', 'นส. ':'หญิง','นาง':'หญิง','นาง ':'หญิง','นาง.':'หญิง', 'นางl':'หญิง','นางสาว':'หญิง','นางสาว ':'หญิง', 'นางสาว                   ':'หญิง','นาน':'ชาย', 'นาบ':'ชาย',
                                  'นาย':'ชาย','นาย ':'ชาย','นาย  ':'ชาย', 'นาว':'หญิง', 'นาวสาว':'หญิง','นา่ง':'หญิง', 'น่าย':'ชาย','พจอ.':'ไม่ระบุ','พระ':'ชาย', 'พระครุ':'ไม่ระบุ', 'พระปลัด':'ไม่ระบุ', 'พลฯ':'ไม่ระบุ','ร.ต.':'ไม่ระบุ', 'ร.ต.ต.':'ไม่ระบุ',
                                  'ร.ต.ท.':'ไม่ระบุ','ร.ต.อ.':'ไม่ระบุ','รต.':'ไม่ระบุ','ว่าที่ ร.ต.':'ไม่ระบุ', 'ว่าที่ ร.ท.':'ไม่ระบุ','ว่าที่ร้อยตรี':'ไม่ระบุ','ส.อ.':'ไม่ระบุ',  'ืนาง':'หญิง', 'เด็กชาย':'ชาย', 'เด็กหญิง':'หญิง'},inplace=True)
##แทนเพศหญิง,ชาย,ไม่ระบุ
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:6619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
data1_alldb[['gender']] =data1_alldb[['gender']].fillna('ไม่ระบุ') #แทนค่าว่างด้วย 'ไม่ระบุ'
data1_alldb  ## แสดงตาราง
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
#        Unnamed: 0   user                                RowKey care  \
# 190           190  06223                        kfpwuaqldj.png  NaN
# 191           191  12015  00859DB9-1BD9-4825-B246-3DC25EFD1924  NaN
# 192           192  91811  1376ACA2-AFA5-4457-967A-D2FCF908E6A5  NaN
# 193           193  95821  1914EE67-CD8F-47EE-A968-2772911AA5DF  NaN
# 194           194  13361  1A219EE7-3647-4D7D-A8C0-AE638E69D889  NaN
# ...           ...    ...                                   ...  ...
# 39812       39812  99999  F45E78D3-7D89-47A3-8207-C705377E0E0A  NaN
# ...

# %%
set(data1_alldb['gender']) #เรียกดู set ของ gender
# Out:
# {'ชาย', 'หญิง', 'ไม่ระบุ'}

# %% [markdown]
# # ▶ อื่นๆที่เห็นว่าเป็นประโยชน์ [age]

# %%
print(data1_alldb.dtypes) #พบว่าค่า age   เป็นobject
# Out:
# Unnamed: 0       int64
# user            object
# RowKey          string
# care            object
# date            object
# ov              object
# phone           string
# site            object
# time            object
# urine           string
# pid             object
# PartitionKey    object
# gender          object
# age             object
# dtype: object

# %%
age_drop = data1_alldb.dropna(subset=['age']) #dropna column age

# %%
age_drop ['age']=age_drop ['age'].astype('int64')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data1_alldb = age_drop[(age_drop ['age'] <=100) & (age_drop ['age'] >=1)]  #เลือกข้อมูลอายุที่มากกว่า1 ปี น้อยกว่า100 ปี 
data1_alldb ## แสดงตาราง
# Out:
#        Unnamed: 0   user                                RowKey care  \
# 191           191  12015  00859DB9-1BD9-4825-B246-3DC25EFD1924  NaN
# 192           192  91811  1376ACA2-AFA5-4457-967A-D2FCF908E6A5  NaN
# 193           193  95821  1914EE67-CD8F-47EE-A968-2772911AA5DF  NaN
# 194           194  13361  1A219EE7-3647-4D7D-A8C0-AE638E69D889  NaN
# 195           195  28241  1AFBC992-AF2F-4F97-AE6D-443F30ED8402  NaN
# ...           ...    ...                                   ...  ...
# 39416       39416  26462                        ieotqfnqcq.png  NaN
# 39417       39417  26462                        cywpeqziic.png  NaN
# 39418       39418  26462  65DE7A37-62D2-4B7F-A494-89A89D5594A7  NaN
# 39419       39419  26462  85F0F443-D3B6-40DD-BD69-81C8D696E0DC  NaN
# 39420       39420  26462                        vdxxgljykj.png  NaN
#
#                       date ov       phone   site      time  \
# 191    2022-03-30 00:00:00  4  iPhone12,3  06307  14:46:08
# ...

# %%
data1_alldb.isnull().any() # ตรวจสอบหาค่า missing
# Out:
# Unnamed: 0      False
# user            False
# RowKey          False
# care             True
# date            False
# ov              False
# phone           False
# site            False
# time            False
# urine           False
# pid              True
# PartitionKey    False
# gender          False
# age             False
# dtype: bool

# %%
data1_alldb.isnull().sum()    ##ดูค่าว่าง
# Out:
# Unnamed: 0          0
# user                0
# RowKey              0
# care            37836
# date                0
# ov                  0
# phone               0
# site                0
# time                0
# urine               0
# pid             37836
# PartitionKey        0
# gender              0
# age                 0
# dtype: int64

# %% [markdown]
# **เลือก cloumn ที่ต้องการ**

# %%
data1all_alldb = data1_alldb[['user','RowKey','date','ov','phone','site','time','urine','PartitionKey','gender','age']]   # ชี้ข้อมูลคอลัมน์ที่ต้องการ
data1all_alldb ## แสดงตาราง
# Out:
#         user                                RowKey                 date ov  \
# 191    12015  00859DB9-1BD9-4825-B246-3DC25EFD1924  2022-03-30 00:00:00  4
# 192    91811  1376ACA2-AFA5-4457-967A-D2FCF908E6A5  2022-03-30 00:00:00  4
# 193    95821  1914EE67-CD8F-47EE-A968-2772911AA5DF  2022-03-30 00:00:00  3
# 194    13361  1A219EE7-3647-4D7D-A8C0-AE638E69D889  2022-03-29 00:00:00  3
# 195    28241  1AFBC992-AF2F-4F97-AE6D-443F30ED8402  2022-03-31 00:00:00  0
# ...      ...                                   ...                  ... ..
# 39416  26462                        ieotqfnqcq.png  2022-03-22 00:00:00  1
# 39417  26462                        cywpeqziic.png  2022-03-21 00:00:00  2
# 39418  26462  65DE7A37-62D2-4B7F-A494-89A89D5594A7  2022-03-22 00:00:00  2
# 39419  26462  85F0F443-D3B6-40DD-BD69-81C8D696E0DC  2022-03-21 00:00:00  0
# 39420  26462                        vdxxgljykj.png  2022-03-21 00:00:00  1
#
# ...

# %%
data1all_alldb.isnull().any() # ตรวจสอบหาค่า missing
# Out:
# user            False
# RowKey          False
# date            False
# ov              False
# phone           False
# site            False
# time            False
# urine           False
# PartitionKey    False
# gender          False
# age             False
# dtype: bool

# %% [markdown]
# ##Data 2  hospital_list.xlsx

# %%
data2_hospital = pd.read_excel(os.path.join(path,'hospital_list.xlsx')) #การนำเข้าไฟล์ที่มีตัวแปรคือdata2_hospital
data2_hospital ## แสดงตาราง
# Out:
#        hcode                                               name  zone_code  \
# 0      00001                สำนักงานสาธารณสุขจังหวัดสมุทรปราการ          6
# 1      00002                    สำนักงานสาธารณสุขจังหวัดนนทบุรี          4
# 2      00003                   สำนักงานสาธารณสุขจังหวัดปทุมธานี          4
# 3      00004            สำนักงานสาธารณสุขจังหวัดพระนครศรีอยุธยา          4
# 4      00005                    สำนักงานสาธารณสุขจังหวัดอ่างทอง          4
# ...      ...                                                ...        ...
# 17098  99990  ศูนย์สุขภาพชุมชนโรงพยาบาลอุตรดิตถ์(สาขา 2 วัดท...          2
# 17099  99991                   ศูนย์สุขภาพชุมชนโรงพยาบาลกุยบุรี          5
# 17100  99993                        ศูนย์สุขภาพชุมชนตำบลวัดเพลง          5
# 17101  99996                        คลินิกทันตกรรม สสจ.ศรีสะเกษ         10
# 17102  99998                          ศูนย์สุขภาพชุมชนตำบลบางแพ          5
#
# ...

# %%
data2_hospital = data2_hospital[['hcode','zone_code','name','province','amphur','tambon']] ##เลือกเฉพาะcolumnที่ต้องการ
data2_hospital  ## แสดงตาราง
# Out:
#        hcode  zone_code                                               name  \
# 0      00001          6                สำนักงานสาธารณสุขจังหวัดสมุทรปราการ
# 1      00002          4                    สำนักงานสาธารณสุขจังหวัดนนทบุรี
# 2      00003          4                   สำนักงานสาธารณสุขจังหวัดปทุมธานี
# 3      00004          4            สำนักงานสาธารณสุขจังหวัดพระนครศรีอยุธยา
# 4      00005          4                    สำนักงานสาธารณสุขจังหวัดอ่างทอง
# ...      ...        ...                                                ...
# 17098  99990          2  ศูนย์สุขภาพชุมชนโรงพยาบาลอุตรดิตถ์(สาขา 2 วัดท...
# 17099  99991          5                   ศูนย์สุขภาพชุมชนโรงพยาบาลกุยบุรี
# 17100  99993          5                        ศูนย์สุขภาพชุมชนตำบลวัดเพลง
# 17101  99996         10                        คลินิกทันตกรรม สสจ.ศรีสะเกษ
# 17102  99998          5                          ศูนย์สุขภาพชุมชนตำบลบางแพ
#
#               province            amphur     tambon
# ...

# %%
data2_hospital= data2_hospital[(data2_hospital['hcode'].astype(str).str.isdigit()) & (data2_hospital['hcode'].str.len() == 5)]      # เลือกมาเฉพาะ คอลัมน์ hcode ที่เป็นตัวเลข & มีตัวเลข เท่ากับ 5 ตัว
data2_hospital## แสดงตาราง
# Out:
#        hcode  zone_code                                               name  \
# 0      00001          6                สำนักงานสาธารณสุขจังหวัดสมุทรปราการ
# 1      00002          4                    สำนักงานสาธารณสุขจังหวัดนนทบุรี
# 2      00003          4                   สำนักงานสาธารณสุขจังหวัดปทุมธานี
# 3      00004          4            สำนักงานสาธารณสุขจังหวัดพระนครศรีอยุธยา
# 4      00005          4                    สำนักงานสาธารณสุขจังหวัดอ่างทอง
# ...      ...        ...                                                ...
# 17098  99990          2  ศูนย์สุขภาพชุมชนโรงพยาบาลอุตรดิตถ์(สาขา 2 วัดท...
# 17099  99991          5                   ศูนย์สุขภาพชุมชนโรงพยาบาลกุยบุรี
# 17100  99993          5                        ศูนย์สุขภาพชุมชนตำบลวัดเพลง
# 17101  99996         10                        คลินิกทันตกรรม สสจ.ศรีสะเกษ
# 17102  99998          5                          ศูนย์สุขภาพชุมชนตำบลบางแพ
#
#               province            amphur     tambon
# ...

# %%
data2_hospital.isnull().any() # ตรวจสอบหาค่า missing
# Out:
# hcode        False
# zone_code    False
# name          True
# province     False
# amphur        True
# tambon        True
# dtype: bool

# %%
data2_hospital[['name']] = data2_hospital[['name']].fillna('ไม่ระบุ')
data2_hospital[['amphur']] =data2_hospital[['amphur']].fillna('ไม่ระบุ')
data2_hospital[['tambon']] = data2_hospital[['tambon']].fillna('ไม่ระบุ')
#แทนค่า ไม่ระบุ ในค่าว่าง
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
data2_hospital.isnull().any()  # ตรวจสอบหาค่า missing
# Out:
# hcode        False
# zone_code    False
# name         False
# province     False
# amphur       False
# tambon       False
# dtype: bool

# %%
data2_hospital.isnull().sum()    ## ดูค่าว่าง
# Out:
# hcode        0
# zone_code    0
# name         0
# province     0
# amphur       0
# tambon       0
# dtype: int64

# %% [markdown]
# # ▶ Merge Table ตารางที่1 และตารางที่2

# %%
data1all_alldb #ตารางที่1 ไฟล์ alldb.csv
# Out:
#         user                                RowKey                 date ov  \
# 191    12015  00859DB9-1BD9-4825-B246-3DC25EFD1924  2022-03-30 00:00:00  4
# 192    91811  1376ACA2-AFA5-4457-967A-D2FCF908E6A5  2022-03-30 00:00:00  4
# 193    95821  1914EE67-CD8F-47EE-A968-2772911AA5DF  2022-03-30 00:00:00  3
# 194    13361  1A219EE7-3647-4D7D-A8C0-AE638E69D889  2022-03-29 00:00:00  3
# 195    28241  1AFBC992-AF2F-4F97-AE6D-443F30ED8402  2022-03-31 00:00:00  0
# ...      ...                                   ...                  ... ..
# 39416  26462                        ieotqfnqcq.png  2022-03-22 00:00:00  1
# 39417  26462                        cywpeqziic.png  2022-03-21 00:00:00  2
# 39418  26462  65DE7A37-62D2-4B7F-A494-89A89D5594A7  2022-03-22 00:00:00  2
# 39419  26462  85F0F443-D3B6-40DD-BD69-81C8D696E0DC  2022-03-21 00:00:00  0
# 39420  26462                        vdxxgljykj.png  2022-03-21 00:00:00  1
#
# ...

# %%
data2_hospital #ตารางที่2 hospital_list.xlsx
# Out:
#        hcode  zone_code                                               name  \
# 0      00001          6                สำนักงานสาธารณสุขจังหวัดสมุทรปราการ
# 1      00002          4                    สำนักงานสาธารณสุขจังหวัดนนทบุรี
# 2      00003          4                   สำนักงานสาธารณสุขจังหวัดปทุมธานี
# 3      00004          4            สำนักงานสาธารณสุขจังหวัดพระนครศรีอยุธยา
# 4      00005          4                    สำนักงานสาธารณสุขจังหวัดอ่างทอง
# ...      ...        ...                                                ...
# 17098  99990          2  ศูนย์สุขภาพชุมชนโรงพยาบาลอุตรดิตถ์(สาขา 2 วัดท...
# 17099  99991          5                   ศูนย์สุขภาพชุมชนโรงพยาบาลกุยบุรี
# 17100  99993          5                        ศูนย์สุขภาพชุมชนตำบลวัดเพลง
# 17101  99996         10                        คลินิกทันตกรรม สสจ.ศรีสะเกษ
# 17102  99998          5                          ศูนย์สุขภาพชุมชนตำบลบางแพ
#
#               province            amphur     tambon
# ...

# %%
data_Final = data1all_alldb.merge(data2_hospital,how='left',left_on='site',right_on='hcode') ## เชื่อมตารางdata1all_alldb กับdata2_hospital ด้วย site และ hcode
data_Final## แสดงตาราง
# Out:
#         user                                RowKey                 date ov  \
# 0      12015  00859DB9-1BD9-4825-B246-3DC25EFD1924  2022-03-30 00:00:00  4
# 1      91811  1376ACA2-AFA5-4457-967A-D2FCF908E6A5  2022-03-30 00:00:00  4
# 2      95821  1914EE67-CD8F-47EE-A968-2772911AA5DF  2022-03-30 00:00:00  3
# 3      13361  1A219EE7-3647-4D7D-A8C0-AE638E69D889  2022-03-29 00:00:00  3
# 4      28241  1AFBC992-AF2F-4F97-AE6D-443F30ED8402  2022-03-31 00:00:00  0
# ...      ...                                   ...                  ... ..
# 37831  26462                        ieotqfnqcq.png  2022-03-22 00:00:00  1
# 37832  26462                        cywpeqziic.png  2022-03-21 00:00:00  2
# 37833  26462  65DE7A37-62D2-4B7F-A494-89A89D5594A7  2022-03-22 00:00:00  2
# 37834  26462  85F0F443-D3B6-40DD-BD69-81C8D696E0DC  2022-03-21 00:00:00  0
# 37835  26462                        vdxxgljykj.png  2022-03-21 00:00:00  1
#
# ...

# %% [markdown]
# # ▶ Save table

# %%
data_Final.to_csv(os.path.join(path,'data_Final.csv'))

# %% [markdown]
# # ▶ DashBoard

# %% [markdown]
# https://datastudio.google.com/s/lq8ziMMCPFI
