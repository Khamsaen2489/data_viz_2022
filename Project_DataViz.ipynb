# %% [markdown]
# <a href="https://colab.research.google.com/github/Khamsaen2489/data_viz_2022/blob/main/Project_DataViz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project กลุ่ม**
#
# * ทำ Dashboard ของ Data Covid (ตั้งแต่วันที่ 12/01/2020 - 18/03/2022)
# * ใช้ข้อมูลภูมิภาค
# * ข้อมูลอื่นที่เลือกเอง

# %% [markdown]
# # **รายชื่อสมาชิกในกลุ่ม**
# **ชื่อกลุ่ม** : ไข่ดาวเจียว
#
# 1.  นางสาวสุภาภรณ์ บุตุธรรม  623020543-8
# 2.  นายคำแสน  แก้วพิภพ       623020761-8
# 3.  นางสาววิกานดา หงษ์บุญมี  623020764-2
#
# ***Basic Programming for Data Science and Data Visualization***

# %%
import pandas as pd  # pandas เป็น Package ที่ใช้เกี่ยวกับการจัดการข้อมูลที่เป็นตาราง , เรียกใช้โดยการ import แล้วตามด้วยชื่อ Package

# %%
from google.colab import drive  # เชื่อมต่อกับ google drive ที่เราเก็บข้อมูลไว้
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os # เป็น package ที่เอาไว้จัดการไฟล์และเอาไว้ดูที่มาของไฟล์หรือ path

# %%
path = '/content/drive/My Drive/ Data_Group_Project' #ระบุให้ชี้ไปที่โฟลเดอร์ใน google drive ที่เราเซฟไฟล์ไว้ คือ โฟลเดอร์ Project_DataViz2022

# %% [markdown]
# # **โหลดข้อมูล Covid-19 ทั้ง 4 ชุด**

# %% [markdown]
# ## **ชุดข้อมูลที่ 1**

# %%
data_01 = pd.read_csv(os.path.join(path,'confirmed-cases.csv')) # ไฟล์ที่เราต้องการ
data_01 # print data ดูว่ามันหน้าตาเป็นยังไง
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#            No. announce_date Notified date   sex   age Unit nationality  \
# 0            1     12/1/2020           NaN  หญิง  61.0   ปี       China
# 1            2     17/1/2020           NaN  หญิง  74.0   ปี       China
# 2            3     22/1/2020           NaN  หญิง  73.0   ปี    Thailand
# 3            4     22/1/2020           NaN   ชาย  68.0   ปี       China
# 4            5     24/1/2020           NaN  หญิง  66.0   ปี       China
# ...        ...           ...           ...   ...   ...  ...         ...
# 839766  839767     12/8/2021     11/8/2021   ชาย  52.0   ปี         NaN
# 839767  839768     12/8/2021     11/8/2021   ชาย  34.0   ปี    Thailand
# 839768  839769     12/8/2021     11/8/2021   ชาย  31.0   ปี    Thailand
# ...

# %% [markdown]
# ## **ชุดข้อมูลที่ 2**

# %%
data_02 = pd.read_csv(os.path.join(path,'confirmed-cases-since-120864.csv')) # ไฟล์ที่เราต้องการ
data_02 # print data ดูว่ามันหน้าตาเป็นยังไง
# Out:
#              No. announce_date Notified date   sex   age Unit nationality  \
# 0         816990     12/8/2021     11/8/2021   ชาย   7.0   ปี    Thailand
# 1         816991     12/8/2021     11/8/2021   ชาย   1.0   ปี    Thailand
# 2         816992     12/8/2021     11/8/2021   ชาย  35.0   ปี    Thailand
# 3         816993     12/8/2021     11/8/2021  หญิง  33.0   ปี    Thailand
# 4         816994     12/8/2021     11/8/2021  หญิง  14.0   ปี    Thailand
# ...          ...           ...           ...   ...   ...  ...         ...
# 1042163  1859153    25/10/2021    24/10/2021   ชาย  45.0   ปี         NaN
# 1042164  1859154    25/10/2021    24/10/2021   ชาย  31.0   ปี         NaN
# 1042165  1859155    25/10/2021    24/10/2021   ชาย  31.0   ปี         NaN
# 1042166  1859156    25/10/2021    24/10/2021   ชาย  24.0   ปี         NaN
# 1042167  1859157    25/10/2021    24/10/2021   ชาย  25.0   ปี         NaN
#
#         province_of_isolation                                         risk  \
# ...

# %% [markdown]
# ## **ชุดข้อมูลที่ 3**

# %%
data_03 = pd.read_csv(os.path.join(path,'confirmed-cases-since-271064.csv')) # ไฟล์ที่เราต้องการ
data_03 # print data ดูว่ามันหน้าตาเป็นยังไง
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#              No. announce_date Notified date   sex   age Unit nationality  \
# 0        1859158    26/10/2021    25/10/2021   ชาย  20.0   ปี    Thailand
# 1        1859159    26/10/2021    25/10/2021  หญิง  42.0   ปี    Thailand
# 2        1859160    26/10/2021    25/10/2021  หญิง  33.0   ปี    Thailand
# 3        1859161    26/10/2021    25/10/2021  หญิง  52.0   ปี    Thailand
# 4        1859162    26/10/2021    25/10/2021  หญิง  84.0   ปี    Thailand
# ...          ...           ...           ...   ...   ...  ...         ...
# 1010454  2869612     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# 1010455  2869613     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# 1010456  2869614     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# ...

# %% [markdown]
# ## **ชุดข้อมูลที่ 4**

# %%
data_04 = pd.read_csv(os.path.join(path,'confirmed-cases-since-280265.csv')) # ไฟล์ที่เราต้องการ
data_04 # print data ดูว่ามันหน้าตาเป็นยังไง
# Out:
#             No. announce_date Notified date   sex   age Unit nationality  \
# 0       2869617     28/2/2022     27/2/2022   ชาย  41.0   ปี    Thailand
# 1       2869618     28/2/2022     27/2/2022  หญิง  45.0   ปี    Thailand
# 2       2869619     28/2/2022     27/2/2022  หญิง  40.0   ปี    Thailand
# 3       2869620     28/2/2022     27/2/2022   ชาย  44.0   ปี    Thailand
# 4       2869621     28/2/2022     27/2/2022   ชาย  11.0   ปี    Thailand
# ...         ...           ...           ...   ...   ...  ...         ...
# 433548  3303165     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433549  3303166     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433550  3303167     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433551  3303168     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433552  3303169     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
#
#        province_of_isolation                                         risk  \
# ...

# %% [markdown]
# # **รวมข้อมูล Covid-19 ทั้ง 4 ชุดเข้าด้วยกัน**

# %%
data_covid = pd.concat([data_01, data_02, data_03, data_04])
data_covid
# Out:
#             No. announce_date Notified date   sex   age Unit nationality  \
# 0             1     12/1/2020           NaN  หญิง  61.0   ปี       China
# 1             2     17/1/2020           NaN  หญิง  74.0   ปี       China
# 2             3     22/1/2020           NaN  หญิง  73.0   ปี    Thailand
# 3             4     22/1/2020           NaN   ชาย  68.0   ปี       China
# 4             5     24/1/2020           NaN  หญิง  66.0   ปี       China
# ...         ...           ...           ...   ...   ...  ...         ...
# 433548  3303165     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433549  3303166     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433550  3303167     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433551  3303168     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433552  3303169     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
#
#        province_of_isolation                              risk  \
# ...

# %% [markdown]
# # **แสดง Columns ที่สนใจ**

# %%
data_covid = data_covid[['announce_date','sex','age','nationality','risk','province_of_onset']]
data_covid
# Out:
#        announce_date   sex   age nationality  \
# 0          12/1/2020  หญิง  61.0       China
# 1          17/1/2020  หญิง  74.0       China
# 2          22/1/2020  หญิง  73.0    Thailand
# 3          22/1/2020   ชาย  68.0       China
# 4          24/1/2020  หญิง  66.0       China
# ...              ...   ...   ...         ...
# 433548     18/3/2022  หญิง   NaN         NaN
# 433549     18/3/2022  หญิง   NaN         NaN
# 433550     18/3/2022  หญิง   NaN         NaN
# 433551     18/3/2022  หญิง   NaN         NaN
# 433552     18/3/2022  หญิง   NaN         NaN
#
#                                     risk province_of_onset
# 0       คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 1       คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 2       คนต่างชาติเดินทางมาจากต่างประเทศ            นครปฐม
# 3       คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 4       คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# ...                                  ...               ...
# ...

# %% [markdown]
# # **ตรวจสอบค่า Missing ของตาราง data_covid**

# %%
data_covid.isnull().any() # ดูว่าคอลัมน์ไหนมีค่า missing บ้าง สรุปคือทุกคอลัมน์ไม่มีค่า  missing
# Out:
# announce_date        False
# sex                   True
# age                   True
# nationality           True
# risk                  True
# province_of_onset     True
# dtype: bool

# %% [markdown]
# ### **แก้ค่า Missing ของคอลัมน์ 'age'**

# %%
# แทนค่า Missing ของคอลัมน์ 'age' ด้วยค่า mean ของ 'age'
data_covid[['age']].mean()       
avg_age = data_covid[['age']].mean() 
data_covid[['age']] = data_covid[['age']].fillna(avg_age)   # แทนค่าเฉลี่ยของอายุลงไปในค่าว่าง
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
data_covid.isnull().any() # ดูว่าคอลัมน์ไหนมีค่า missing บ้าง จะเห็นว่าคอลัมน์ 'age' เป็น False นั่นคือไม่มีค่า missing
# Out:
# announce_date        False
# sex                   True
# age                   True
# nationality           True
# risk                  True
# province_of_onset     True
# dtype: bool

# %% [markdown]
# ### **แก้ค่า Missing ของคอลัมน์ 'sex'**

# %%
# แทนค่า Missing ของคอลัมน์ 'sex' เป็น 'ไม่ระบุ'
data_covid[['sex']] = data_covid[['sex']].fillna('ไม่ระบุ')
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
data_covid.isnull().any() # ดูว่าคอลัมน์ไหนมีค่า missing บ้าง จะเห็นว่าคอลัมน์ 'sex' เป็น False นั่นคือไม่มีค่า missing
# Out:
# announce_date        False
# sex                  False
# age                   True
# nationality           True
# risk                  True
# province_of_onset     True
# dtype: bool

# %% [markdown]
# ### **แก้ค่า Missing ของคอลัมน์ 'risk'**

# %%
set(data_covid['risk'])      # ลองดู set ข้อมูลของคอลัมน์ 'risk'
# Out:
# {' Samui plus',
#  '10.อื่นๆ',
#  '2.สัมผัสผู้ติดเชื้อ',
#  '8.สำรวจกลุ่มเสี่ยง (survey)',
#  '9.ขอตรวจหาเชื้อเอง',
#  'ACF รองเมือง',
#  'ACF สนามกีฬาธูปะเตมีย์',
#  'ACF สนามกีฬาไทย-ญี่ปุ่น',
#  'ACF สีลม',
#  'ACF เคหะหลักสี่',
#  'BKK Sandbox',
#  'Chonburi Sandbox',
#  'Cluster Icon siam',
#  "Cluster Memory 90's กรุงเทพมหานคร",
#  'Cluster New Jazz กรุงเทพมหานคร',
#  'Cluster The Lounge Salaya',
#  'Cluster คลองเตย',
#  'Cluster งานมอเตอร์ โชว์',
#  'Cluster จนท. สนามบินสุวรรณภูมิ',
#  'Cluster จันทบุรี',
#  'Cluster จันทบุรี (ชาวกินี )',
#  'Cluster จันทบุรี (ชาวกินี)',
#  'Cluster ชลบุรี',
#  'Cluster ชลบุรี บริษัทไดกิ้น',
#  'Cluster ชลบุรี โรงเบียร์ 90',
#  'Cluster ตราด',
#  'Cluster ตราด ',
#  'Cluster ตลาดนนทบุรี',
#  'Cluster ตลาดบางพลี',
#  'Cluster ตลาดบางแค',
#  'Cluster ตลาดพรพัฒน์',
#  'Cluster ตลาดสี่มุมเมือง',
#  'Cluster บริษัทศรีสวัสดิ์',
#  'Cluster บางแค',
#  'Cluster บ่อนพัทยา/ชลบุรี',
#  'Cluster บ่อนเทพารักษ์',
#  'Cluster บ่อนไก่อ่างทอง',
# ...

# %%
data_covid[['risk']] = data_covid[['risk']].fillna('ไม่มีข้อมูล')  # แทนค่า Missing ของคอลัมน์ 'risk' ด้วย 'ไม่มีข้อมูล'
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
data_covid.isnull().any()       # ดูว่าคอลัมน์ไหนมีค่า missing บ้าง จะเห็นว่าคอลัมน์ 'risk' เป็น False นั่นคือไม่มีค่า missing
# Out:
# announce_date        False
# sex                  False
# age                   True
# nationality           True
# risk                 False
# province_of_onset     True
# dtype: bool

# %% [markdown]
# ### **แก้ค่า Missing ของคอลัมน์ 'province_of_onset'**

# %%
set(data_covid['province_of_onset'])     # ลองดู set ข้อมูลของคอลัมน์ 'province_of_onset'
# Out:
# {'\tประจวบคีรีขันธ์',
#  'USA',
#  nan,
#  '\xa0กาญจนบุรี',
#  '\xa0ชลบุรี',
#  '\xa0ตราด',
#  '\xa0นครปฐม',
#  '\xa0สมุทรสงคราม',
#  '\xa0สมุทรสาคร',
#  '\xa0อุทัยธานี',
#  'กทม',
#  'กทม.',
#  'กบินทร์บุรี',
#  'กระบี่',
#  'กระบี่ี่',
#  'กรุงเทพ',
#  'กรุงเทพมหานคร',
#  'กรุงเทพมหานคร.',
#  'กรุงเทพมหานคร. / พระนครศรีอยุธยา',
#  'กรุงเทพมหานคร. / ศรีสะเกษ',
#  'กรุงเทพฯ',
#  'กะทู้',
#  'กัมพูชา',
#  'กาญจนบุรี',
#  'กาญจบุรี',
#  'กาญนบุรี',
#  'กาฬสิน',
#  'กาฬสินธิ์',
#  'กาฬสินธุ์',
#  'กาฬสินธุ์\xa0',
#  'กาฬสินธ์',
#  'กำเพงเพชร',
#  'กำแพง',
#  'กำแพงเพชร',
#  'กำแพงเพชร\xa0',
#  'กําแพงเพชร',
#  'ขอนแก่น',
#  'ขอนแก่น\xa0',
#  'ขอนแก่่น',
#  'ขัยนาท',
#  'ขัยภูมิ',
#  'ขานุวรลักษณ์บุรี',
#  'คนไทยเดินทางกลับจากต่างประเทศ',
#  'คลองเตย',
#  'จ.กรุงเทพมหานคร',
#  'จ.ภูเก็ต',
#  'จ.ราชบุรี',
#  'จ.สุราษฎร์ธานี',
#  'จังหวัดสมุทรสาคร',
#  'จันทบุรี',
#  'ฉะเชองเทราร',
#  'ฉะเชิงเทรา',
#  'ชมพร',
#  'ชลบุรี',
#  'ชลบุรี\t',
#  'ชลบุรี\xa0',
#  'ชลบุุรี',
#  'ชอนแก่น',
# ...

# %%
# แทนค่า Missing ของคอลัมน์ 'province_of_onset' ด้วย 'ไม่ระบุ'
data_covid[['province_of_onset']] = data_covid[['province_of_onset']].fillna('ไม่ระบุ')
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
data_covid.isnull().any() # ดูว่าคอลัมน์ไหนมีค่า missing บ้าง จะเห็นว่าคอลัมน์ 'province_of_onset' เป็น False นั่นคือไม่มีค่า missing
# Out:
# announce_date        False
# sex                  False
# age                   True
# nationality           True
# risk                 False
# province_of_onset    False
# dtype: bool

# %%
# แทนค่า Missing ของคอลัมน์ 'nationality' เป็น 'ไม่ระบุ'
data_covid[['nationality']] = data_covid[['nationality']].fillna('ไม่ระบุ')
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
data_covid.isnull().any() # ดูว่าคอลัมน์ไหนมีค่า missing บ้าง จะเห็นว่าคอลัมน์ 'nationality' เป็น False นั่นคือไม่มีค่า missing
# Out:
# announce_date        False
# sex                  False
# age                   True
# nationality          False
# risk                 False
# province_of_onset    False
# dtype: bool

# %%
set(data_covid['province_of_onset']) # ลองดู set ข้อมูลของคอลัมน์ 'province_of_onset'
# Out:
# {'\tประจวบคีรีขันธ์',
#  'USA',
#  '\xa0กาญจนบุรี',
#  '\xa0ชลบุรี',
#  '\xa0ตราด',
#  '\xa0นครปฐม',
#  '\xa0สมุทรสงคราม',
#  '\xa0สมุทรสาคร',
#  '\xa0อุทัยธานี',
#  'กทม',
#  'กทม.',
#  'กบินทร์บุรี',
#  'กระบี่',
#  'กระบี่ี่',
#  'กรุงเทพ',
#  'กรุงเทพมหานคร',
#  'กรุงเทพมหานคร.',
#  'กรุงเทพมหานคร. / พระนครศรีอยุธยา',
#  'กรุงเทพมหานคร. / ศรีสะเกษ',
#  'กรุงเทพฯ',
#  'กะทู้',
#  'กัมพูชา',
#  'กาญจนบุรี',
#  'กาญจบุรี',
#  'กาญนบุรี',
#  'กาฬสิน',
#  'กาฬสินธิ์',
#  'กาฬสินธุ์',
#  'กาฬสินธุ์\xa0',
#  'กาฬสินธ์',
#  'กำเพงเพชร',
#  'กำแพง',
#  'กำแพงเพชร',
#  'กำแพงเพชร\xa0',
#  'กําแพงเพชร',
#  'ขอนแก่น',
#  'ขอนแก่น\xa0',
#  'ขอนแก่่น',
#  'ขัยนาท',
#  'ขัยภูมิ',
#  'ขานุวรลักษณ์บุรี',
#  'คนไทยเดินทางกลับจากต่างประเทศ',
#  'คลองเตย',
#  'จ.กรุงเทพมหานคร',
#  'จ.ภูเก็ต',
#  'จ.ราชบุรี',
#  'จ.สุราษฎร์ธานี',
#  'จังหวัดสมุทรสาคร',
#  'จันทบุรี',
#  'ฉะเชองเทราร',
#  'ฉะเชิงเทรา',
#  'ชมพร',
#  'ชลบุรี',
#  'ชลบุรี\t',
#  'ชลบุรี\xa0',
#  'ชลบุุรี',
#  'ชอนแก่น',
#  'ชัยนาถ',
# ...

# %%
len(set(data_covid['province_of_onset']))
# Out:
# 437

# %%
#ทำข้อมูลให้เหมือนกัน
data_covid['province_of_onset'].replace({'\tประจวบคีรีขันธ์':'ประจวบคีรีขันธ์',
 'USA':'กรุงเทพมหานคร',
 '\xa0กาญจนบุรี':'กาญจนบุรี',
 '\xa0ชลบุรี':'ชลบุรี',
 '\xa0ตราด':'ตราด',
 '\xa0นครปฐม':'นครปฐม',
 '\xa0สมุทรสงคราม':'สมุทรสงคราม',
 '\xa0สมุทรสาคร':'สมุทรสาคร',
 '\xa0อุทัยธานี':'อุทัยธานี',
 'กทม':'กรุงเทพมหานคร',
 'กทม.':'กรุงเทพมหานคร',
 'กบินทร์บุรี':'ปราจีนบุรี',
 'กระบี่':'กระบี่',
 'กระบี่ี่':'กระบี่',
 'กรุงเทพ':'กรุงเทพมหานคร',
 'กรุงเทพมหานคร':'กรุงเทพมหานคร',
 'กรุงเทพมหานคร.':'กรุงเทพมหานคร',
 'กรุงเทพมหานคร. / พระนครศรีอยุธยา':'กรุงเทพมหานคร',
 'กรุงเทพมหานคร. / ศรีสะเกษ':'กรุงเทพมหานคร',
 'กรุงเทพฯ':'กรุงเทพมหานคร',
 'กะทู้':'ไม่ระบุ',
 'กัมพูชา':'กรุงเทพมหานคร',
 'กาญจนบุรี':'กาญจนบุรี',
 'กาญจบุรี':'กาญจนบุรี',
 'กาญนบุรี':'กาญจนบุรี',
 'กาฬสิน':'กาฬสินธุ์',
 'กาฬสินธิ์':'กาฬสินธุ์',
 'กาฬสินธุ์':'กาฬสินธุ์',
 'กาฬสินธุ์\xa0':'กาฬสินธุ์',
 'กาฬสินธ์':'กาฬสินธุ์',
 'กำเพงเพชร':'กำแพงเพชร',
 'กำแพง':'กำแพงเพชร',
 'กำแพงเพชร':'กำแพงเพชร',
 'กำแพงเพชร\xa0':'กำแพงเพชร',
 'กําแพงเพชร':'กำแพงเพชร',
 'ขอนแก่น':'ขอนแก่น',
 'ขอนแก่น\xa0':'ขอนแก่น',
 'ขอนแก่่น':'ขอนแก่น',
 'ขัยนาท':'ชัยนาท',
 'ขัยภูมิ':'ชัยภูมิ',
 'ขานุวรลักษณ์บุรี':'กำแพงเพชร',
 'คนไทยเดินทางกลับจากต่างประเทศ':'กรุงเทพมหานคร',
 'คลองเตย':'กรุงเทพมหานคร',
 'จ.กรุงเทพมหานคร':'กรุงเทพมหานคร',
 'จ.ภูเก็ต':'ภูเก็ต',
 'จ.ราชบุรี':'ราชบุรี',
 'จ.สุราษฎร์ธานี':'สุราษฎร์ธานี',
 'จังหวัดสมุทรสาคร':'สมุทรสาคร',
 'จันทบุรี':'จันทบุรี',
 'ฉะเชองเทราร':'ฉะเชิงเทรา',
 'ฉะเชิงเทรา':'ฉะเชิงเทรา',
 'ชมพร':'ชุมพร',
 'ชลบุรี':'ชลบุรี',
 'ชลบุรี\t':'ชลบุรี',
 'ชลบุรี\xa0':'ชลบุรี',
 'ชลบุุรี':'ชลบุรี',
 'ชอนแก่น':'ขอนแก่น',
 'ชัยนาถ':'ชัยนาท',
 'ชัยนาท':'ชัยนาท',
 'ชัยบาดาล':'ลพบุรี',
 'ชัยภูมิ':'ชัยภูมิ',
 'ชัยภูมิ\xa0':'ชัยภูมิ',
 'ชุมพร':'ชุมพร',
 'ชุุมพร':'ชุมพร',
 'ชุุุมพร':'ชุมพร',
 'ดอนมดแดง':'อุบลราชธานี',
 'ดินแดง':'กรุงเทพมหานคร',
 'ตรัง':'ตรัง',
 'ตรััง':'ตรัง',
 'ตราด':'ตราด',
 'ตราด\xa0':'ตราด',
 'ตาก':'ตาก',
 'ตากใบ':'นราธิวาส',
 'ต่างจังหวัด':'กรุงเทพมหานคร',
 'ทุ่งเสลี่ยม':'สุโขทัย',
 'ท้ายบ้าน':'สมุทรปราการ',
 'ธารโต':'ยะลา',
 'นคนปฐม':'นครปฐม',
 'นคปฐม':'นครปฐม',
 'นครนปฐม':'นครปฐม',
 'นครนาชสีมา':'นครราชสีมา',
 'นครนายก':'นครนายก',
 'นครปฐม':'นครปฐม',
 'นครปฐม\xa0':'นครปฐม',
 'นครปบม':'นครปฐม',
 'นครพนม':'นครพนม',
 'นครพนม\xa0':'นครพนม',
 'นครยายก':'นครนายก',
 'นครราขสีมา':'นครราชสีมา',
 'นครราชธานี':'นครราชสีมา',
 'นครราชศรีมา':'นครราชสีมา',
 'นครราชสสีมา':'นครราชสีมา',
 'นครราชสีมา':'นครราชสีมา',
 'นครราชสีมา ลพบุรี':'นครราชสีมา',
 'นครราชสีมา\xa0':'นครราชสีมา',
 'นครศรธรรมราช':'นครศรีธรรมราช',
 'นครศรี':'นครศรีธรรมราช',
 'นครศรีธรมมราช':'นครศรีธรรมราช',
 'นครศรีธรมราช':'นครศรีธรรมราช',
 'นครศรีธรรมราข':'นครศรีธรรมราช',
 'นครศรีธรรมราช':'นครศรีธรรมราช',
 'นครศรีฯ':'นครศรีธรรมราช',
 'นครศรีีธรรมราช':'นครศรีธรรมราช',
 'นครศร๊ธรรมราช':'นครศรีธรรมราช',
 'นครศร๊ะรรมราช':'นครศรีธรรมราช',
 'นครสรรค์':'นครสวรรค์',
 'นครสรีธรรมราช':'นครศรีธรรมราช',
 'นครสวรรค':'นครสวรรค์',
 'นครสวรรค์':'นครสวรรค์',
 'นครสวรรค์\xa0':'นครสวรรค์',
 'นครสีธรรมราช':'นครศรีธรรมราช',
 'นครฯ':'นครราชสีมา',
 'นคราชสีมา':'นครราชสีมา',
 'นครีศรีธรรมราช':'นครศรีธรรมราช',
 'นตรนายก':'นครนายก',
 'นตรปฐม':'นครปฐม',
 'นนทบุรี':'นนทบุรี',
 'นนทบุรี\xa0':'นนทบุรี',
 'นนทบุุรี':'นนทบุรี',
 'นนทุบรี':'นนทบุรี',
 'นนทุรี':'นนทบุรี',
 'นนมบุรี':'นนทบุรี',
 'นรศรีธรรมราช':'นครศรีธรรมราช',
 'นราธิวาส':'นราธิวาส',
 'นราธิวาส\u200b':'นราธิวาส',
 'นราธฺวาส':'นราธิวาส',
 'นอกเขต':'ไม่ระบุ',
 'นาราธิวาส':'นราธิวาส',
 'นาวัง':'หนองบัวลำภู',
 'น่าน':'น่าน',
 'น่าน/ฉะเชิงเทรา':'น่าน',
 'บางกรวย':'นนทบุรี',
 'บางกะปิ':'กรุงเทพมหานคร',
 'บางนา':'กรุงเทพมหานคร',
 'บางปะอิน':'กรุงเทพมหานคร',
 'บางละมุง':'ชลบุรี',
 'บางศรีเมือง':'นนทบุรี',
 'บางเพียง':'สมุทรปราการ',
 'บึงกาฬ':'บึงกาฬ',
 'บึงโขงหลง':'บึงกาฬ',
 'บุรีรัมภ์':'บุรีรัมย์',
 'บุรีรัมย์':'บุรีรัมย์',
 'บุรีรัมย์\xa0':'บุรีรัมย์',
 'บุรีรัยม์':'บุรีรัมย์',
 'บุรีรีมย์':'บุรีรัมย์',
 'บ้านหลวง':'น่าน',
 'ปจ':'ไม่ระบุ',
 'ปทึมธานี':'ปทุมธานี',
 'ปทุทธานี':'ปทุมธานี',
 'ปทุมฑานี':'ปทุมธานี',
 'ปทุมทานี':'ปทุมธานี',
 'ปทุมธาน':'ปทุมธานี',
 'ปทุมธานี':'ปทุมธานี',
 'ปทุมธานี.':'ปทุมธานี',
 'ปทุมธานี\xa0':'ปทุมธานี',
 'ปทุมธานีี':'ปทุมธานี',
 'ปทุมาธานี':'ปทุมธานี',
 'ปทุุมธานี':'ปทุมธานี',
 'ปธุมธานี':'ปทุมธานี',
 'ปมุมธานี':'ปทุมธานี',
 'ประจวนคีรีขันธ็':'ประจวบคีรีขันธ์',
 'ประจวบ':'ประจวบคีรีขันธ์',
 'ประจวบคิรีขันธ์':'ประจวบคีรีขันธ์',
 'ประจวบคีรขันธ์':'ประจวบคีรีขันธ์',
 'ประจวบคีรขัันธ์':'ประจวบคีรีขันธ์',
 'ประจวบคีรีขัน':'ประจวบคีรีขันธ์',
 'ประจวบคีรีขันธื':'ประจวบคีรีขันธ์',
 'ประจวบคีรีขันธฺ':'ประจวบคีรีขันธ์',
 'ประจวบคีรีขันธ์':'ประจวบคีรีขันธ์',
 'ประจวบคีรีขันธ์\xa0':'ประจวบคีรีขันธ์',
 'ประจวบคีรีขันธ์์':'ประจวบคีรีขันธ์',
 'ประจวบคีรีขัันธ์':'ประจวบคีรีขันธ์',
 'ประจวบคีีรีขันธ์':'ประจวบคีรีขันธ์',
 'ประจวบฯ':'ประจวบคีรีขันธ์',
 'ประทุมธานี':'ปทุมธานี',
 'ประเทศกัมพูชา':'กรุงเทพมหานคร',
 'ปราจีนบุรี':'ปราจีนบุรี',
 'ปราจีบุรี':'ปราจีนบุรี',
 'ปลวกแดง':'ระยอง',
 'ปลายพระยา':'กระบี่',
 'ปอยเปต':'กรุงเทพมหานคร',
 'ปัตตนรี':'ปัตตานี',
 'ปัตตานนี':'ปัตตานี',
 'ปัตตานี':'ปัตตานี',
 'ปัตตานีี':'ปัตตานี',
 'ปัตาตานี':'ปัตตานี',
 'ปัว':'เพชรบุรี',
 'ปััตตานี':'ปัตตานี',
 'ปุทมธานี':'ปทุมธานี',
 'ป่าโมก':'สุโขทัย',
 'พม่า':'กรุงเทพมหานคร',
 'พรหมพิราม':'พิษณุโลก',
 'พระนครศรียุธยา':'พระนครศรีอยุธยา',
 'พระนครศรีอยุทธยา':'พระนครศรีอยุธยา',
 'พระนครศรีอยุทยา':'พระนครศรีอยุธยา',
 'พระนครศรีอยุธยา':'พระนครศรีอยุธยา',
 'พระนครศรีอยุธยา\xa0':'พระนครศรีอยุธยา',
 'พะเยา':'พะเยา',
 'พังงา':'พังงา',
 'พัทยา':'ชลบุรี',
 'พัทลุง':'พัทลุง',
 'พัทลุุง':'พัทลุง',
 'พัังงา':'พังงา',
 'พิจิตร':'พิจิตร',
 'พิษณุโลก':'พิษณุโลก',
 'พิษณุโลก\xa0':'พิษณุโลก',
 'พิษณูโลก':'พิษณุโลก',
 'ฟินแลนด์':'กรุงเทพมหานคร',
 'ภาษีเจริญ':'กรุงเทพมหานคร',
 'ภุเก็ต':'ภูเก็ต',
 'ภูุเก็ต':'ภูเก็ต',
 'ภููเก็ต':'ภูเก็ต',
 'ภูเก็ต':'ภูเก็ต',
 'ภูเก็็ต':'ภูเก็ต',
 'ภูเพียง':'น่าน',
 'มหาสาคาม':'มหาสารคาม',
 'มหาสารคาม':'มหาสารคาม',
 'มาเลเซีย':'กรุงเทพมหานคร',
 'มุกดาหาร':'มุกดาหาร',
 'มุกาดหาร':'มุกดาหาร',
 'ยะลา':'ยะลา',
 'ยานนาวา':'กรุงเทพมหานคร',
 'ยโสธร':'ยโสธร',
 'ร.จ.จ.นราธิวาส':'นราธิวาส',
 'รอ':'ไม่ระบุ',
 'ระนอง':'ระนอง',
 'ระบุ':'ไม่ระบุ',
 'ระยอง':'ระยอง',
 'ระยอง\xa0':'ระยอง',
 'ระอยง':'ระยอง',
 'ราชบบุรี':'ราชบุรี',
 'ราชบุรี':'ราชบุรี',
 'ราชบุรีี':'ราชบุรี',
 'ราชบุรี\u200b':'ราชบุรี',
 'ราชุรี':'ราชบุรี',
 'ราชเทวี':'กรุงเทพมหานคร',
 'ร้องกวาง':'แพร่',
 'ร้อยเอ็ด':'ร้อยเอ็ด',
 'ลบุรี':'ลพบุรี',
 'ลพบุรี':'ลพบุรี',
 'ลพบุรี.':'ลพบุรี',
 'ลพบุรี\xa0':'ลพบุรี',
 'ลอง':'ไม่ระบุ',
 'ลาดกระบัง':'กรุงเทพมหานคร',
 'ลาดพร้าว':'กรุงเทพมหานคร',
 'ลาว':'กรุงเทพมหานคร',
 'ลำปาง':'ลำปาง',
 'ลำพูน':'ลำพูน',
 'ลำพูน\u200b':'ลำพูน',
 'ลำพููน':'ลำพูน',
 'ลำลูกกา':'กรุงเทพมหานคร',
 'วังชิ้น':'แพร่',
 'วังทอง':'พิษณุโลก',
 'วิเศษชัยชาญ':'อ่างทอง',
 'ศรีษะสะเกษ':'ศรีสะเกษ',
 'ศรีษะเกษ':'ศรีสะเกษ',
 'ศรีสระเกษ':'ศรีสะเกษ',
 'ศรีสะเกษ':'ศรีสะเกษ',
 'ศีรสะเกษ':'ศรีสะเกษ',
 'สกลนคร':'สกลนคร',
 'สครสวรรค์':'นครสวรรค์',
 'สงขลา':'สงขลา',
 'สงขลา\u200b':'สงขลา',
 'สตูล':'สตูล',
 'สถานที่ทำงาน':'ไม่ระบุ',
 'สพรรณบุรี':'สุพรรณบุรี',
 'สมถทรปราการ':'สมุทรปราการ',
 'สมทรสงคราม':'สมุทรสงคราม',
 'สมทรสาคร':'สมุทรสาคร',
 'สมุครปราการ':'สมุทรปราการ',
 'สมุครสาคร':'สมุทรสาคร',
 'สมุท':'สมุทรปราการ',
 'สมุทปราการ':'สมุทรปราการ',
 'สมุทรปรากร':'สมุทรปราการ',
 'สมุทรปรากรร':'สมุทรปราการ',
 'สมุทรปรากา':'สมุทรปราการ',
 'สมุทรปราการ':'สมุทรปราการ',
 'สมุทรปราการ\xa0':'สมุทรปราการ',
 'สมุทรศาคร':'สมุทรสาคร',
 'สมุทรสงคราม':'สมุทรสาคร',
 'สมุทรสาคร':'สมุทรสาคร',
 'สมุทรสาคร\xa0':'สมุทรสาคร',
 'สมุทรสาคา':'สมุทรสาคร',
 'สมุทรสาคาร':'สมุทรสาคร',
 'สมุทรสาทร':'สมุทรสาคร',
 'สมุทรสารคร':'สมุทรสาคร',
 'สมุทราปราการ':'สมุทรปราการ',
 'สมุทราสาคร':'สมุทรสาคร',
 'สมุทสงคราม':'สมุทรสงคราม',
 'สมุทสาคร':'สมุทรสาคร',
 'สมุย':'สุราษฎร์ธานี',
 'สมุุทรปราการ':'สมุทรปราการ',
 'สมุุทรสงคราม':'สมุทรสงคราม',
 'สมุุทรสาคร':'สมุทรสาคร',
 'สระก้ว':'สระแก้ว',
 'สระบุรี':'สระบุรี',
 'สระบุรี\xa0':'สระบุรี',
 'สระแก้ว':'สระแก้ว',
 'สรินทร์':'สุรินทร์',
 'สวิสเซอร์แลนด์':'กรุงเทพมหานคร',
 'สอง':'ไม่ระบุ',
 'สองแคว':'เชียงใหม่',
 'สะพานสูง':'กรุงเทพมหานคร',
 'สะแก้ว':'สระแก้ว',
 'สัตหีบ':'ชลบุรี',
 'สัมผัสผู้ป่วยยืนยัน COVID20':'ไม่ระบุ',
 'สามุทรสาคร':'สมุทรสาคร',
 'สารคาม':'มหาสารคาม',
 'สารภี':'เชียงใหม่',
 'สิงห์บุรี':'สิงห์บุรี',
 'สิงห์บุรี\xa0':'สิงห์บุรี',
 'สุทรปราการ':'สมุทรปราการ',
 'สุพรรญบุรี':'สุพรรณบุรี',
 'สุพรรณบุรั':'สุพรรณบุรี',
 'สุพรรณบุรี':'สุพรรณบุรี',
 'สุพรรณบุรี\xa0':'สุพรรณบุรี',
 'สุมทรปราการ':'สมุทรปราการ',
 'สุมทรสาคร':'สมุทรสาคร',
 'สุมุทรปราการ':'สมุทรปราการ',
 'สุมุทรสาคร':'สมุทรสาคร',
 'สุระบุรี':'สระบุรี',
 'สุราษ':'สุราษฎร์ธานี',
 'สุราษฎณ์ธานี':'สุราษฎร์ธานี',
 'สุราษฎธานี':'สุราษฎร์ธานี',
 'สุราษฎร์':'สุราษฎร์ธานี',
 'สุราษฎร์ธานี':'สุราษฎร์ธานี',
 'สุราษฎร์ฯ':'สุราษฎร์ธานี',
 'สุราษฎร์์ธานี':'สุราษฎร์ธานี',
 'สุราษฎ์ธานี':'สุราษฎร์ธานี',
 'สุราษฏร์ธานี':'สุราษฎร์ธานี',
 'สุราษธานี':'สุราษฎร์ธานี',
 'สุราษร์ฎธานี':'สุราษฎร์ธานี',
 'สุราษร์ธานี':'สุราษฎร์ธานี',
 'สุราษฯ':'สุราษฎร์ธานี',
 'สุรินทรื':'สุรินทร์',
 'สุรินทร์':'สุรินทร์',
 'สุรินทร์ 32150':'สุรินทร์',
 'สุรินทร์,รีสะเกษ':'สุรินทร์',
 'สุรินทร์\xa0':'สุรินทร์',
 'สุริมทร์':'สุรินทร์',
 'สุริะแก้ว':'สระแก้ว',
 'สุวรรณภูมิ':'กรุงเทพมหานคร',
 'สุุพรรณบุรี':'สุพรรณบุรี',
 'สุุราษฎร์ธานี':'สุราษฎร์ธานี',
 'สุุราษฏร์ธานี':'สุราษฎร์ธานี',
 'สุุราษฯ':'สุราษฎร์ธานี',
 'สุุรินทร์':'สุรินทร์',
 'สุุุโขทัย':'สุโขทัย',
 'สุโขทับ':'สุโขทัย',
 'สุโขทัย':'สุโขทัย',
 'สุโขทัย\xa0':'สุโขทัย',
 'สูงเม่น':'แพร่',
 'หนวงบัวลำภู':'หนองบัวลำภู',
 'หนองคาย':'หนองคาย',
 'หนองงคาย':'หนองคาย',
 'หนองบัวภู':'หนองบัวลำภู',
 'หนองบัวลำพูน':'หนองบัวลำภู',
 'หนองบัวลำภู':'หนองบัวลำภู',
 'หนองบัวลําภู':'หนองบัวลำภู',
 'หนองบััวลำภู':'หนองบัวลำภู',
 'หนองม่วงไข่':'แพร่',
 'หนอบัวลำภู':'หนองบัวลำภู',
 'หลายจังหวัด':'ไม่ระบุ',
 'หัวหิน':'ชลบุรี',
 'ห้วยขวาง':'กรุงเทพมหานคร',
 'อยุทธยา':'พระนครศรีอยุธยา',
 'อยุธยา':'พระนครศรีอยุธยา',
 'อยุุธยา':'พระนครศรีอยุธยา',
 'อำนาจเจริญ':'อำนาจเจริญ',
 'อำนาจเจิญ':'อำนาจเจริญ',
 'อำนาญเจริญ':'อำนาจเจริญ',
 'อำนาเจริญ':'อำนาจเจริญ',
 'อิสราเอล':'กรุงเทพมหานคร',
 'อุดธานี':'อุดรธานี',
 'อุดร':'อุดรธานี',
 'อุดรธาณี':'อุดรธานี',
 'อุดรธานี':'อุดรธานี',
 'อุดรธานี\xa0':'อุดรธานี',
 'อุดรธานีี':'อุดรธานี',
 'อุดรราชธานี':'อุดรธานี',
 'อุตรดิตถ์':'อุตรดิตถ์',
 'อุตรดิตถ์\xa0':'อุตรดิตถ์',
 'อุตรดิตถ์์':'อุตรดิตถ์',
 'อุตรดิษถ์':'อุตรดิตถ์',
 'อุตรดิิตถ์':'อุตรดิตถ์',
 'อุตรติดถ์':'อุตรดิตถ์',
 'อุทัยธานี':'อุทัยธานี',
 'อุทัยานี':'อุทัยธานี',
 'อุบลราขธานี':'อุบลราชธานี',
 'อุบลราชธานี':'อุบลราชธานี',
 'อุบลราชธานี\xa0':'อุบลราชธานี',
 'อุุครดิตถ์':'อุตรดิตถ์',
 'อุุดรธาน':'อุดรธานี',
 'อุุดรธานี':'อุดรธานี',
 'อุุตรดิตถ์':'อุตรดิตถ์',
 'อุุทัยธานี':'อุทัยธานี',
 'อุุบลราชธานี':'อุบลราชธานี',
 'อ่งทอง':'อ่างทอง',
 'อ่างทอง':'อ่างทอง',
 'อ่างทอง\xa0':'อ่างทอง',
 'อํานาจเจริญ':'อำนาจเจริญ',
 'เชิงเทรา':'ฉะเชิงเทรา',
 'เชียงราย':'เชียงราย',
 'เชียงใหม่':'เชียงใหม่',
 'เชียรใหญ่':'เชียงใหม่',
 'เชีียงราย':'เชียงราย',
 'เชีียงใหม่':'เชียงใหม่',
 'เด่นชัย':'แพร่',
 'เพขรบุรี':'เพชรบุรี',
 'เพขรบูรณื':'เพชรบูรณ์',
 'เพขรบูรณ์':'เพชรบูรณ์',
 'เพชรบุรณ์':'เพชรบูรณ์',
 'เพชรบุรี':'เพชรบุรี',
 'เพชรบุรึ':'เพชรบุรี',
 'เพชรบุุรี':'เพชรบุรี',
 'เพชรบุูรณ์':'เพชรบูรณ์',
 'เพชรบูรณ์':'เพชรบูรณ์',
 'เพชรบูรณ์\xa0':'เพชรบูรณ์',
 'เพชรบูร์':'เพชรบูรณ์',
 'เพชรบููรณ์':'เพชรบูรณ์',
 'เมือง':'ไม่ระบุ',
 'เมืองตาก':'ตาก',
 'เมืองน่าน':'น่าน',
 'เมืองปัตตานี':'ปัตตานี',
 'เรือ':'ไม่ระบุ',
 'เลย':'เลย',
 'เลย\xa0':'เลย',
 'เวียงจันทร์':'กรุงเทพมหานคร',
 'เวียงสา':'กรุงเทพมหานคร',
 'แพร่':'แพร่',
 'แม่ทะ':'ลำปาง',
 'แม่ฮ่องสอน':'แม่ฮ่องสอน',
 'แล้วป่วย':'ไม่ระบุ',
 'โพธิ์ทอง':'อ่างทอง',
 'ไชโย':'อ่างทอง',
 'ไม่มีชื่อหอพัก':'ไม่ระบุ',
 'ไม่ระบุ':'ไม่ระบุ'}, inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:6619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
len(set(data_covid['province_of_onset'])) # มีทั้งหมด 78 ค่าเพราะว่ามีค่าที่ชื่อว่า 'ไม่ระบุ'
# Out:
# 78

# %%
# สร้างตารางที่รวมจำนวนผู้ติดเชื้อโควิด - 19 ในแต่ละจังหวัด
data_groupby = data_covid.groupby('province_of_onset').size().reset_index(name='จำนวนผู้ติดเชื้อ')  
data_groupby
# Out:
#    province_of_onset  จำนวนผู้ติดเชื้อ
# 0             กระบี่             17668
# 1      กรุงเทพมหานคร            572177
# 2          กาญจนบุรี             24534
# 3          กาฬสินธุ์             18596
# 4          กำแพงเพชร             13107
# ..               ...               ...
# 73         เพชรบูรณ์             18497
# 74               เลย              9990
# 75              แพร่              5676
# 76        แม่ฮ่องสอน              4145
# 77           ไม่ระบุ            400249
#
# [78 rows x 2 columns]

# %%
covid_dropped = data_covid.dropna() # drop ค่าอายุที่ว่างออกจากตาราง

# %%
covid_dropped
# Out:
#        announce_date      sex   age nationality  \
# 0          12/1/2020     หญิง  61.0       China
# 1          17/1/2020     หญิง  74.0       China
# 2          22/1/2020     หญิง  73.0    Thailand
# 3          22/1/2020      ชาย  68.0       China
# 4          24/1/2020     หญิง  66.0       China
# ...              ...      ...   ...         ...
# 433445     18/3/2022  ไม่ระบุ  43.0     ไม่ระบุ
# 433446     18/3/2022  ไม่ระบุ  21.0     ไม่ระบุ
# 433447     18/3/2022  ไม่ระบุ  22.0     ไม่ระบุ
# 433448     18/3/2022  ไม่ระบุ  25.0     ไม่ระบุ
# 433449     18/3/2022  ไม่ระบุ  64.0     ไม่ระบุ
#
#                                     risk province_of_onset
# 0       คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 1       คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 2       คนต่างชาติเดินทางมาจากต่างประเทศ            นครปฐม
# 3       คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 4       คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# ...

# %%
data_covid_finish = covid_dropped.merge(data_groupby,how='left',left_on='province_of_onset',right_on = 'province_of_onset') 
data_covid_finish
# Out:
#         announce_date      sex   age nationality  \
# 0           12/1/2020     หญิง  61.0       China
# 1           17/1/2020     หญิง  74.0       China
# 2           22/1/2020     หญิง  73.0    Thailand
# 3           22/1/2020      ชาย  68.0       China
# 4           24/1/2020     หญิง  66.0       China
# ...               ...      ...   ...         ...
# 3057763     18/3/2022  ไม่ระบุ  43.0     ไม่ระบุ
# 3057764     18/3/2022  ไม่ระบุ  21.0     ไม่ระบุ
# 3057765     18/3/2022  ไม่ระบุ  22.0     ไม่ระบุ
# 3057766     18/3/2022  ไม่ระบุ  25.0     ไม่ระบุ
# 3057767     18/3/2022  ไม่ระบุ  64.0     ไม่ระบุ
#
#                                      risk province_of_onset  จำนวนผู้ติดเชื้อ
# 0        คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร            572177
# 1        คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร            572177
# 2        คนต่างชาติเดินทางมาจากต่างประเทศ            นครปฐม             70398
# ...

# %% [markdown]
# # **สร้างตารางภูมิภาค**

# %%
region1 = { 'จังหวัด': ['อำนาจเจริญ','บึงกาฬ', 'บุรีรัมย์', 'ชัยภูมิ', 'กาฬสินธุ์', 'ขอนแก่น', 'เลย', 'มหาสารคาม', 'มุกดาหาร', 'นครพนม', 'นครราชสีมา', 'หนองบัวลำภู', 'หนองคาย', 'ร้อยเอ็ด', 'สกลนคร', 'ศรีสะเกษ', 'สุรินทร์', 'อุบลราชธานี', 'อุดรธานี', 'ยโสธร'],
             'ภูมิศาสตร์': ['ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ'],
             'การเมือง': ['ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ'],
             'อุตุนิยมวิทยา': ['ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ'],
             'การท่องเที่ยว': ['ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ']
}
region2 = { 'จังหวัด': ['เชียงใหม่', 'เชียงราย', 'ลำปาง', 'ลำพูน', 'แม่ฮ่องสอน', 'น่าน', 'พะเยา', 'แพร่', 'อุตรดิตถ์'],
             'ภูมิศาสตร์': ['เหนือ', 'เหนือ', 'เหนือ', 'เหนือ', 'เหนือ', 'เหนือ', 'เหนือ', 'เหนือ', 'เหนือ'],
             'การเมือง': ['เหนือ', 'เหนือ', 'เหนือ', 'เหนือ', 'เหนือ', 'เหนือ', 'เหนือ', 'เหนือ', 'เหนือ'],
             'อุตุนิยมวิทยา': ['เหนือ', 'เหนือ', 'เหนือ', 'เหนือ', 'เหนือ', 'เหนือ', 'เหนือ', 'เหนือ', 'เหนือ'],
             'การท่องเที่ยว': ['เหนือ', 'เหนือ', 'เหนือ', 'เหนือ', 'เหนือ', 'เหนือ', 'เหนือ', 'เหนือ', 'เหนือ']
}
region3 = { 'จังหวัด': ['ตาก'],
             'ภูมิศาสตร์': ['ตะวันตก'],
             'การเมือง': ['เหนือ'],
             'อุตุนิยมวิทยา': ['เหนือ'],
             'การท่องเที่ยว': ['เหนือ']
}
region4 = { 'จังหวัด': ['สุโขทัย', 'พิษณุโลก', 'พิจิตร', 'กำแพงเพชร', 'เพชรบูรณ์'],
             'ภูมิศาสตร์': ['กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง'],
             'การเมือง': ['เหนือ', 'เหนือ', 'เหนือ', 'เหนือ', 'เหนือ'],
             'อุตุนิยมวิทยา': ['เหนือ', 'เหนือ', 'เหนือ', 'เหนือ', 'เหนือ'],
             'การท่องเที่ยว': ['เหนือ', 'เหนือ', 'เหนือ', 'เหนือ', 'เหนือ']
}
region5 = { 'จังหวัด': ['นครสวรรค์', 'อุทัยธานี'],
             'ภูมิศาสตร์': ['กลาง','กลาง'],
             'การเมือง': ['เหนือ','เหนือ'],
             'อุตุนิยมวิทยา': ['กลาง','กลาง'],
             'การท่องเที่ยว': ['เหนือ','เหนือ']
}
region6 = { 'จังหวัด': ['อ่างทอง', 'ชัยนาท', 'พระนครศรีอยุธยา', 'กรุงเทพมหานคร','ลพบุรี', 'นครปฐม', 'นนทบุรี', 'ปทุมธานี', 'สมุทรปราการ', 'สมุทรสาคร', 'สมุทรสงคราม', 'สระบุรี', 'สิงห์บุรี', 'สุพรรณบุรี'],
             'ภูมิศาสตร์': ['กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง'],
             'การเมือง': ['กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง'],
             'อุตุนิยมวิทยา': ['กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง'],
             'การท่องเที่ยว': ['กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง']
}
region7 = { 'จังหวัด': ['นครนายก'],
             'ภูมิศาสตร์': ['กลาง'],
             'การเมือง': ['กลาง'],
             'อุตุนิยมวิทยา': ['ตะวันออก'],
             'การท่องเที่ยว': ['กลาง']
}
region8 = { 'จังหวัด': ['ฉะเชิงเทรา', 'จันทบุรี', 'ชลบุรี', 'ปราจีนบุรี', 'ระยอง', 'สระแก้ว', 'ตราด'],
             'ภูมิศาสตร์': ['ตะวันออก', 'ตะวันออก', 'ตะวันออก', 'ตะวันออก', 'ตะวันออก', 'ตะวันออก', 'ตะวันออก'],
             'การเมือง': ['กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง'],
             'อุตุนิยมวิทยา': ['ตะวันออก', 'ตะวันออก', 'ตะวันออก', 'ตะวันออก', 'ตะวันออก', 'ตะวันออก', 'ตะวันออก'],
             'การท่องเที่ยว': ['ตะวันออก', 'ตะวันออก', 'ตะวันออก', 'ตะวันออก', 'ตะวันออก', 'ตะวันออก', 'ตะวันออก']
}
region9 = { 'จังหวัด': ['กาญจนบุรี', 'ราชบุรี'],
             'ภูมิศาสตร์': ['ตะวันตก','ตะวันตก'],
             'การเมือง': ['กลาง','กลาง'],
             'อุตุนิยมวิทยา': ['กลาง','กลาง'],
             'การท่องเที่ยว': ['กลาง','กลาง']
}
region10 = { 'จังหวัด': ['เพชรบุรี', 'ประจวบคีรีขันธ์'],
             'ภูมิศาสตร์': ['ตะวันตก','ตะวันตก'],
             'การเมือง': ['กลาง','กลาง'],
             'อุตุนิยมวิทยา': ['ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย','ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย'],
             'การท่องเที่ยว': ['กลาง','กลาง']
}
region11 = { 'จังหวัด': ['ชุมพร', 'นครศรีธรรมราช','นราธิวาส', 'ปัตตานี', 'พัทลุง', 'สงขลา', 'สุราษฎร์ธานี', 'ยะลา'],
             'ภูมิศาสตร์': ['ใต้', 'ใต้', 'ใต้', 'ใต้', 'ใต้', 'ใต้', 'ใต้', 'ใต้'],
             'การเมือง': ['ใต้', 'ใต้', 'ใต้', 'ใต้', 'ใต้', 'ใต้', 'ใต้', 'ใต้'],
             'อุตุนิยมวิทยา': ['ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย', 'ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย', 'ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย', 'ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย', 'ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย', 'ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย', 'ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย', 'ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย'],
             'การท่องเที่ยว': ['ใต้', 'ใต้', 'ใต้', 'ใต้', 'ใต้', 'ใต้', 'ใต้', 'ใต้']
}
region12 = { 'จังหวัด': ['กระบี่', 'พังงา', 'ภูเก็ต', 'ระนอง', 'สตูล', 'ตรัง'],
             'ภูมิศาสตร์': ['ใต้', 'ใต้', 'ใต้', 'ใต้', 'ใต้', 'ใต้'],
             'การเมือง': ['ใต้', 'ใต้', 'ใต้', 'ใต้', 'ใต้', 'ใต้'],
             'อุตุนิยมวิทยา': ['ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน', 'ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน', 'ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน', 'ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน', 'ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน', 'ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน'],
             'การท่องเที่ยว': ['ใต้', 'ใต้', 'ใต้', 'ใต้', 'ใต้', 'ใต้']
}

# %%
df_region1 = pd.DataFrame.from_dict(region1)
df_region2 = pd.DataFrame.from_dict(region2)
df_region3 = pd.DataFrame.from_dict(region3)
df_region4 = pd.DataFrame.from_dict(region4)
df_region5 = pd.DataFrame.from_dict(region5)
df_region6 = pd.DataFrame.from_dict(region6)
df_region7 = pd.DataFrame.from_dict(region7)
df_region8 = pd.DataFrame.from_dict(region8)
df_region9 = pd.DataFrame.from_dict(region9)
df_region10 = pd.DataFrame.from_dict(region10)
df_region11 = pd.DataFrame.from_dict(region11)
df_region12 = pd.DataFrame.from_dict(region12)

# %% [markdown]
# # **ตารางข้อมูล Region**

# %%
region_new = pd.concat([df_region1, df_region2, df_region3, df_region4, df_region5, df_region6,
                            df_region7, df_region8, df_region9, df_region10, df_region11, df_region12])  

region_new
# Out:
#        จังหวัด          ภูมิศาสตร์            การเมือง  \
# 0   อำนาจเจริญ  ตะวันออกเฉียงเหนือ  ตะวันออกเฉียงเหนือ
# 1       บึงกาฬ  ตะวันออกเฉียงเหนือ  ตะวันออกเฉียงเหนือ
# 2    บุรีรัมย์  ตะวันออกเฉียงเหนือ  ตะวันออกเฉียงเหนือ
# 3      ชัยภูมิ  ตะวันออกเฉียงเหนือ  ตะวันออกเฉียงเหนือ
# 4    กาฬสินธุ์  ตะวันออกเฉียงเหนือ  ตะวันออกเฉียงเหนือ
# ..         ...                 ...                 ...
# 1        พังงา                 ใต้                 ใต้
# 2       ภูเก็ต                 ใต้                 ใต้
# 3        ระนอง                 ใต้                 ใต้
# 4         สตูล                 ใต้                 ใต้
# 5         ตรัง                 ใต้                 ใต้
#
#                      อุตุนิยมวิทยา       การท่องเที่ยว
# 0               ตะวันออกเฉียงเหนือ  ตะวันออกเฉียงเหนือ
# 1               ตะวันออกเฉียงเหนือ  ตะวันออกเฉียงเหนือ
# 2               ตะวันออกเฉียงเหนือ  ตะวันออกเฉียงเหนือ
# 3               ตะวันออกเฉียงเหนือ  ตะวันออกเฉียงเหนือ
# ...

# %% [markdown]
# # **รวมตาราง Data covid กับตาราง ภูมิภาค**

# %% [markdown]
# *   data_covid_finish
# *   region_new

# %%
data_new= data_covid_finish.merge(region_new,how='left',left_on='province_of_onset',right_on = 'จังหวัด') 
data_new
# Out:
#         announce_date      sex   age nationality  \
# 0           12/1/2020     หญิง  61.0       China
# 1           17/1/2020     หญิง  74.0       China
# 2           22/1/2020     หญิง  73.0    Thailand
# 3           22/1/2020      ชาย  68.0       China
# 4           24/1/2020     หญิง  66.0       China
# ...               ...      ...   ...         ...
# 3057763     18/3/2022  ไม่ระบุ  43.0     ไม่ระบุ
# 3057764     18/3/2022  ไม่ระบุ  21.0     ไม่ระบุ
# 3057765     18/3/2022  ไม่ระบุ  22.0     ไม่ระบุ
# 3057766     18/3/2022  ไม่ระบุ  25.0     ไม่ระบุ
# 3057767     18/3/2022  ไม่ระบุ  64.0     ไม่ระบุ
#
#                                      risk province_of_onset  จำนวนผู้ติดเชื้อ  \
# 0        คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร            572177
# 1        คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร            572177
# 2        คนต่างชาติเดินทางมาจากต่างประเทศ            นครปฐม             70398
# ...

# %% [markdown]
# # **ตรวจสอบค่า Missing ของตาราง data_new**

# %%
data_new.isnull().any() # ดูว่าคอลัมน์ไหนมีค่า missing บ้าง สรุปคือทุกคอลัมน์ไม่มีค่า  missing
# Out:
# announce_date        False
# sex                  False
# age                  False
# nationality          False
# risk                 False
# province_of_onset    False
# จำนวนผู้ติดเชื้อ     False
# จังหวัด               True
# ภูมิศาสตร์            True
# การเมือง              True
# อุตุนิยมวิทยา         True
# การท่องเที่ยว         True
# dtype: bool

# %% [markdown]
# ## **แก้ค่า Missing ของคอลัมน์ 'จังหวัด'**

# %%
# แทนค่า Missing ของคอลัมน์ 'จังหวัด' เป็น 'ไม่ระบุ'
data_new[['จังหวัด']] = data_new[['จังหวัด']].fillna('ไม่ระบุ') ##แทนค่า NaN เป็น ไม่ระบุ

# %%
data_new.isnull().any() # ดูว่าคอลัมน์ไหนมีค่า missing บ้าง จะเห็นว่าคอลัมน์ 'จังหวัด' เป็น False นั่นคือไม่มีค่า missing
# Out:
# announce_date        False
# sex                  False
# age                  False
# nationality          False
# risk                 False
# province_of_onset    False
# จำนวนผู้ติดเชื้อ     False
# จังหวัด              False
# ภูมิศาสตร์            True
# การเมือง              True
# อุตุนิยมวิทยา         True
# การท่องเที่ยว         True
# dtype: bool

# %% [markdown]
# ## **แก้ค่า Missing ของคอลัมน์ 'ภูมิศาสตร์'**

# %%
# แทนค่า Missing ของคอลัมน์ 'ภูมิศาสตร์' เป็น 'ไม่ระบุ'
data_new[['ภูมิศาสตร์']] = data_new[['ภูมิศาสตร์']].fillna('ไม่ระบุ') ##แทนค่า NaN เป็น ไม่ระบุ

# %%
data_new.isnull().any() # ดูว่าคอลัมน์ไหนมีค่า missing บ้าง จะเห็นว่าคอลัมน์ 'ภูมิศาสตร์' เป็น False นั่นคือไม่มีค่า missing
# Out:
# announce_date        False
# sex                  False
# age                  False
# nationality          False
# risk                 False
# province_of_onset    False
# จำนวนผู้ติดเชื้อ     False
# จังหวัด              False
# ภูมิศาสตร์           False
# การเมือง              True
# อุตุนิยมวิทยา         True
# การท่องเที่ยว         True
# dtype: bool

# %% [markdown]
# # **โหลดข้อมูลที่เลือก**

# %% [markdown]
# จำนวนประชากรในประเทศไทย แยกตามพื้นที่

# %%
covid_file_path0= os.path.join(path,'stat_c64.xlsx') #โหลดชุดข้อมูลจำนวนประชากรในประเทศไทย แยกตามพื้นที่
print(covid_file_path0)
# Out:
# /content/drive/My Drive/ Data_Group_Project/stat_c64.xlsx

# %%
data_file = pd.read_excel(covid_file_path0)
data_file
# Out:
#    ปีเดือน  รหัสจังหวัด         ชื่อจังหวัด  รหัสสำนักทะเบียน  \
# 0    ﻿6412            0          ทั่วประเทศ                 0
# 1     6412           10       กรุงเทพมหานคร                 0
# 2     6412           11  จังหวัดสมุทรปราการ                 0
# 3     6412           12      จังหวัดนนทบุรี                 0
# 4     6412           13     จังหวัดปทุมธานี                 0
# ..     ...          ...                 ...               ...
# 73    6412           92         จังหวัดตรัง                 0
# 74    6412           93       จังหวัดพัทลุง                 0
# 75    6412           94      จังหวัดปัตตานี                 0
# 76    6412           95         จังหวัดยะลา                 0
# 77    6412           96     จังหวัดนราธิวาส                 0
#
#    ชื่อสำนักทะเบียน  รหัสตำบล ชื่อตำบล  รหัสหมู่บ้าน ชื่อหมู่บ้าน  \
# 0                 -         0        -             0            -
# 1                 -         0        -             0            -
# ...

# %%
data_city= data_file[['ชื่อจังหวัด','จำนวนประชากรชาย','จำนวนประชากรหญิง','จำนวนประชากรทั้งหมด','จำนวนบ้าน (หลังคาเรือน)']]
data_city
# Out:
#            ชื่อจังหวัด  จำนวนประชากรชาย  จำนวนประชากรหญิง  \
# 0           ทั่วประเทศ         32339118          33832321
# 1        กรุงเทพมหานคร          2592292           2935702
# 2   จังหวัดสมุทรปราการ           645884            710565
# 3       จังหวัดนนทบุรี           599167            689470
# 4      จังหวัดปทุมธานี           563851            626209
# ..                 ...              ...               ...
# 73         จังหวัดตรัง           312693            327095
# 74       จังหวัดพัทลุง           254425            268116
# 75      จังหวัดปัตตานี           360348            369233
# 76         จังหวัดยะลา           269907            272407
# 77     จังหวัดนราธิวาส           400501            409159
#
#     จำนวนประชากรทั้งหมด  จำนวนบ้าน (หลังคาเรือน)
# 0              66171439                 27708635
# 1               5527994                  3147231
# 2               1356449                   733185
# 3               1288637                   728953
# ...

# %% [markdown]
# # **ตรวจสอบค่า Missing ของตาราง data_city**

# %%
data_city.isnull().any() # ดูว่าคอลัมน์ไหนมีค่า missing บ้าง สรุปคือทุกคอลัมน์ไม่มีค่า  missing
# Out:
# ชื่อจังหวัด                False
# จำนวนประชากรชาย            False
# จำนวนประชากรหญิง           False
# จำนวนประชากรทั้งหมด        False
# จำนวนบ้าน (หลังคาเรือน)    False
# dtype: bool

# %%
set(data_city['ชื่อจังหวัด']) # ลองดู set ข้อมูลของคอลัมน์ 'ชื่อจังหวัด'
# Out:
# {'กรุงเทพมหานคร',
#  'จังหวัดกระบี่',
#  'จังหวัดกาญจนบุรี',
#  'จังหวัดกาฬสินธุ์',
#  'จังหวัดกำแพงเพชร',
#  'จังหวัดขอนแก่น',
#  'จังหวัดจันทบุรี',
#  'จังหวัดฉะเชิงเทรา',
#  'จังหวัดชลบุรี',
#  'จังหวัดชัยนาท',
#  'จังหวัดชัยภูมิ',
#  'จังหวัดชุมพร',
#  'จังหวัดตรัง',
#  'จังหวัดตราด',
#  'จังหวัดตาก',
#  'จังหวัดนครนายก',
#  'จังหวัดนครปฐม',
#  'จังหวัดนครพนม',
#  'จังหวัดนครราชสีมา',
#  'จังหวัดนครศรีธรรมราช',
#  'จังหวัดนครสวรรค์',
#  'จังหวัดนนทบุรี',
#  'จังหวัดนราธิวาส',
#  'จังหวัดน่าน',
#  'จังหวัดบึงกาฬ',
#  'จังหวัดบุรีรัมย์',
#  'จังหวัดปทุมธานี',
#  'จังหวัดประจวบคีรีขันธ์',
#  'จังหวัดปราจีนบุรี',
#  'จังหวัดปัตตานี',
#  'จังหวัดพระนครศรีอยุธยา',
#  'จังหวัดพะเยา',
#  'จังหวัดพังงา',
#  'จังหวัดพัทลุง',
#  'จังหวัดพิจิตร',
#  'จังหวัดพิษณุโลก',
#  'จังหวัดภูเก็ต',
#  'จังหวัดมหาสารคาม',
#  'จังหวัดมุกดาหาร',
#  'จังหวัดยะลา',
#  'จังหวัดยโสธร',
#  'จังหวัดระนอง',
#  'จังหวัดระยอง',
#  'จังหวัดราชบุรี',
#  'จังหวัดร้อยเอ็ด',
#  'จังหวัดลพบุรี',
#  'จังหวัดลำปาง',
# ...

# %%
#ทำข้อมูลให้เหมือนกัน
data_city['ชื่อจังหวัด'].replace({'จังหวัดกระบี่':'กระบี่',
 'จังหวัดกาญจนบุรี':'กาญจนบุรี',
 'จังหวัดกาฬสินธุ์':'กาฬสินธุ์',
 'จังหวัดกำแพงเพชร':'กำแพงเพชร',
 'จังหวัดขอนแก่น':'ขอนแก่น',
 'จังหวัดจันทบุรี':'จันทบุรี',
 'จังหวัดฉะเชิงเทรา':'ฉะเชิงเทรา',
 'จังหวัดชลบุรี':'ชลบุรี',
 'จังหวัดชัยนาท':'ชัยนาท',
 'จังหวัดชัยภูมิ':'ชัยภูมิ',
 'จังหวัดชุมพร':'ชุมพร',
 'จังหวัดตรัง':'ตรัง',
 'จังหวัดตราด':'ตราด',
 'จังหวัดตาก':'ตาก',
 'จังหวัดนครนายก':'นครนายก',
 'จังหวัดนครปฐม':'นครปฐม',
 'จังหวัดนครพนม':'นครพนม',
 'จังหวัดนครราชสีมา':'นครราชสีมา',
 'จังหวัดนครศรีธรรมราช':'นครศรีธรรมราช',
 'จังหวัดนครสวรรค์':'นครสวรรค์',
 'จังหวัดนนทบุรี':'นนทบุรี',
 'จังหวัดนราธิวาส':'นราธิวาส',
 'จังหวัดน่าน':'น่าน',
 'จังหวัดบึงกาฬ':'บึงกาฬ',
 'จังหวัดบุรีรัมย์':'บุรีรัมย์',
 'จังหวัดปทุมธานี':'ปทุมธานี',
 'จังหวัดประจวบคีรีขันธ์':'ประจวบคีรีขันธ์',
 'จังหวัดปราจีนบุรี':'ปราจีนบุรี',
 'จังหวัดปัตตานี':'ปัตตานี',
 'จังหวัดพระนครศรีอยุธยา':'พระนครศรีอยุธยา',
 'จังหวัดพะเยา':'พะเยา',
 'จังหวัดพังงา':'พังงา',
 'จังหวัดพัทลุง':'พัทลุง',
 'จังหวัดพิจิตร':'พิจิตร',
 'จังหวัดพิษณุโลก':'พิษณุโลก',
 'จังหวัดภูเก็ต':'ภูเก็ต',
 'จังหวัดมหาสารคาม':'มหาสารคาม',
 'จังหวัดมุกดาหาร':'มุกดาหาร',
 'จังหวัดยะลา':'ยะลา',
 'จังหวัดยโสธร':'ยโสธร',
 'จังหวัดระนอง':'ระนอง',
 'จังหวัดระยอง':'ระยอง',
 'จังหวัดราชบุรี':'ราชบุรี',
 'จังหวัดร้อยเอ็ด':'ร้อยเอ็ด',
 'จังหวัดลพบุรี':'ลพบุรี',
 'จังหวัดลำปาง':'ลำปาง',
 'จังหวัดลำพูน':'ลำพูน',
 'จังหวัดศรีสะเกษ':'ศรีสะเกษ',
 'จังหวัดสกลนคร':'สกลนคร',
 'จังหวัดสงขลา':'สงขลา',
 'จังหวัดสตูล':'สตูล',
 'จังหวัดสมุทรปราการ':'สมุทรปราการ',
 'จังหวัดสมุทรสงคราม':'สมุทรสงคราม',
 'จังหวัดสมุทรสาคร':'สมุทรสาคร',
 'จังหวัดสระบุรี':'สระบุรี',
 'จังหวัดสระแก้ว':'สระแก้ว',
 'จังหวัดสิงห์บุรี':'สิงห์บุรี',
 'จังหวัดสุพรรณบุรี':'สุพรรณบุรี',
 'จังหวัดสุราษฎร์ธานี':'สุราษฎร์ธานี',
 'จังหวัดสุรินทร์':'สุรินทร์',
 'จังหวัดสุโขทัย':'สุโขทัย',
 'จังหวัดหนองคาย':'หนองคาย',
 'จังหวัดหนองบัวลำภู':'หนองบัวลำภู',
 'จังหวัดอำนาจเจริญ':'อำนาจเจริญ',
 'จังหวัดอุดรธานี':'อุดรธานี',
 'จังหวัดอุตรดิตถ์':'อุตรดิตถ์',
 'จังหวัดอุทัยธานี':'อุทัยธานี',
 'จังหวัดอุบลราชธานี':'อุบลราชธานี',
 'จังหวัดอ่างทอง':'อ่างทอง',
 'จังหวัดเชียงราย':'เชียงราย',
 'จังหวัดเชียงใหม่':'เชียงใหม่',
 'จังหวัดเพชรบุรี':'เพชรบุรี',
 'จังหวัดเพชรบูรณ์':'เพชรบูรณ์',
 'จังหวัดเลย':'เลย',
 'จังหวัดแพร่':'แพร่',
 'จังหวัดแม่ฮ่องสอน':'แม่ฮ่องสอน'}, inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:6619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %% [markdown]
# # **รวมตารางข้อมูลทั้งหมด**
# * ข้อมูล Data Covid ข้อมูลภูมิภาค
# * ข้อมูลจำนวนประชากรในประเทศไทย แยกตามพื้นที่

# %%
data_finish = data_new[['announce_date','sex','age','risk','province_of_onset','จำนวนผู้ติดเชื้อ','ภูมิศาสตร์']]
data_finish
# Out:
#         announce_date      sex   age                              risk  \
# 0           12/1/2020     หญิง  61.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1           17/1/2020     หญิง  74.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2           22/1/2020     หญิง  73.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3           22/1/2020      ชาย  68.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4           24/1/2020     หญิง  66.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# ...               ...      ...   ...                               ...
# 3057763     18/3/2022  ไม่ระบุ  43.0                             อื่นๆ
# 3057764     18/3/2022  ไม่ระบุ  21.0                             อื่นๆ
# 3057765     18/3/2022  ไม่ระบุ  22.0                             อื่นๆ
# 3057766     18/3/2022  ไม่ระบุ  25.0                             อื่นๆ
# 3057767     18/3/2022  ไม่ระบุ  64.0                             อื่นๆ
#
#         province_of_onset  จำนวนผู้ติดเชื้อ ภูมิศาสตร์
# 0           กรุงเทพมหานคร            572177       กลาง
# ...

# %% [markdown]
# แก้ไขข้อมูล Sex

# %%
data_finish['sex'].replace({'ช':'ชาย',     # เปลี่ยนข้อมูลให้เขียนเหมือนกัน
                 'นาย':'ชาย',
                 'ร.ต.ท.':'ชาย',
                 'ญ':'หญิง',
                 'หณิง':'หญิง',
                 'หห':'หญิง',
                 '\xa0หญิง':'หญิง',
                 'หญง':'หญิง',
                 'หญิิง':'หญิง'},inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:6619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
set(data_finish['sex'])
# Out:
# {'ชาย', 'หญิง', 'ไม่ระบุ'}

# %%
data_finish_new = data_finish.merge(data_city,how='left',left_on='province_of_onset',right_on = 'ชื่อจังหวัด') 
data_finish_new
# Out:
#         announce_date      sex   age                              risk  \
# 0           12/1/2020     หญิง  61.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1           17/1/2020     หญิง  74.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2           22/1/2020     หญิง  73.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3           22/1/2020      ชาย  68.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4           24/1/2020     หญิง  66.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# ...               ...      ...   ...                               ...
# 3057763     18/3/2022  ไม่ระบุ  43.0                             อื่นๆ
# 3057764     18/3/2022  ไม่ระบุ  21.0                             อื่นๆ
# 3057765     18/3/2022  ไม่ระบุ  22.0                             อื่นๆ
# 3057766     18/3/2022  ไม่ระบุ  25.0                             อื่นๆ
# 3057767     18/3/2022  ไม่ระบุ  64.0                             อื่นๆ
#
#         province_of_onset  จำนวนผู้ติดเชื้อ ภูมิศาสตร์    ชื่อจังหวัด  \
# ...

# %% [markdown]
# # **ตรวจสอบค่า Missing ของตาราง data_finish_new**

# %%
data_finish_new.isnull().any() # ดูว่าคอลัมน์ไหนมีค่า missing บ้าง สรุปคือทุกคอลัมน์ไม่มีค่า  missing
# Out:
# announce_date              False
# sex                        False
# age                        False
# risk                       False
# province_of_onset          False
# จำนวนผู้ติดเชื้อ           False
# ภูมิศาสตร์                 False
# ชื่อจังหวัด                 True
# จำนวนประชากรชาย             True
# จำนวนประชากรหญิง            True
# จำนวนประชากรทั้งหมด         True
# จำนวนบ้าน (หลังคาเรือน)     True
# dtype: bool

# %% [markdown]
# ## **แก้ค่า Missing ของคอลัมน์ 'ชื่อจังหวัด'**

# %%
# แทนค่า Missing ของคอลัมน์ 'ชื่อจังหวัด' เป็น 'ไม่ระบุ'
data_finish_new[['ชื่อจังหวัด']] = data_finish_new[['ชื่อจังหวัด']].fillna('ไม่ระบุ') ##แทนค่า NaN เป็น ไม่ระบุ

# %%
data_finish_new.isnull().any() # ดูว่าคอลัมน์ไหนมีค่า missing บ้าง จะเห็นว่าคอลัมน์ 'ชื่อจังหวัด' เป็น False นั่นคือไม่มีค่า missing
# Out:
# announce_date              False
# sex                        False
# age                        False
# risk                       False
# province_of_onset          False
# จำนวนผู้ติดเชื้อ           False
# ภูมิศาสตร์                 False
# ชื่อจังหวัด                False
# จำนวนประชากรชาย             True
# จำนวนประชากรหญิง            True
# จำนวนประชากรทั้งหมด         True
# จำนวนบ้าน (หลังคาเรือน)     True
# dtype: bool

# %% [markdown]
# ## **แก้ค่า Missing ของคอลัมน์ 'จำนวนประชากรชาย'**

# %%
# แทนค่า Missing ของคอลัมน์ 'จำนวนประชากรชาย' เป็น 'ไม่ระบุ'
data_finish_new[['จำนวนประชากรชาย']] = data_finish_new[['จำนวนประชากรชาย']].fillna('ไม่ระบุ') ##แทนค่า NaN เป็น ไม่ระบุ

# %%
data_finish_new.isnull().any() # ดูว่าคอลัมน์ไหนมีค่า missing บ้าง จะเห็นว่าคอลัมน์ 'จำนวนประชากรชาย' เป็น False นั่นคือไม่มีค่า missing
# Out:
# announce_date              False
# sex                        False
# age                        False
# risk                       False
# province_of_onset          False
# จำนวนผู้ติดเชื้อ           False
# ภูมิศาสตร์                 False
# ชื่อจังหวัด                False
# จำนวนประชากรชาย            False
# จำนวนประชากรหญิง            True
# จำนวนประชากรทั้งหมด         True
# จำนวนบ้าน (หลังคาเรือน)     True
# dtype: bool

# %% [markdown]
# ## **แก้ค่า Missing ของคอลัมน์ 'จำนวนประชากรหญิง'**

# %%
# แทนค่า Missing ของคอลัมน์ 'จำนวนประชากรหญิง' เป็น 'ไม่ระบุ'
data_finish_new[['จำนวนประชากรหญิง']] = data_finish_new[['จำนวนประชากรหญิง']].fillna('ไม่ระบุ') ##แทนค่า NaN เป็น ไม่ระบุ

# %%
data_finish_new.isnull().any() # ดูว่าคอลัมน์ไหนมีค่า missing บ้าง จะเห็นว่าคอลัมน์ 'จำนวนประชากรหญิง' เป็น False นั่นคือไม่มีค่า missing
# Out:
# announce_date              False
# sex                        False
# age                        False
# risk                       False
# province_of_onset          False
# จำนวนผู้ติดเชื้อ           False
# ภูมิศาสตร์                 False
# ชื่อจังหวัด                False
# จำนวนประชากรชาย            False
# จำนวนประชากรหญิง           False
# จำนวนประชากรทั้งหมด         True
# จำนวนบ้าน (หลังคาเรือน)     True
# dtype: bool

# %% [markdown]
# ## **แก้ค่า Missing ของคอลัมน์ 'จำนวนประชากรทั้งหมด'**

# %%
# แทนค่า Missing ของคอลัมน์ 'จำนวนประชากรทั้งหมด' เป็น 'ไม่ระบุ'
data_finish_new[['จำนวนประชากรทั้งหมด']] = data_finish_new[['จำนวนประชากรทั้งหมด']].fillna('ไม่ระบุ') ##แทนค่า NaN เป็น ไม่ระบุ

# %%
data_finish_new.isnull().any() # ดูว่าคอลัมน์ไหนมีค่า missing บ้าง จะเห็นว่าคอลัมน์ 'จำนวนประชากรทั้งหมด' เป็น False นั่นคือไม่มีค่า missing
# Out:
# announce_date              False
# sex                        False
# age                        False
# risk                       False
# province_of_onset          False
# จำนวนผู้ติดเชื้อ           False
# ภูมิศาสตร์                 False
# ชื่อจังหวัด                False
# จำนวนประชากรชาย            False
# จำนวนประชากรหญิง           False
# จำนวนประชากรทั้งหมด        False
# จำนวนบ้าน (หลังคาเรือน)     True
# dtype: bool

# %%
# เปลี่ยนรูปแบบของข้อมูลวันที่ให้เป็น %d/%m/%Y 
data_finish_new['announce_date'] = pd.to_datetime(data_finish_new['announce_date'],format="%d/%m/%Y")
data_finish_new
# Out:
#         announce_date      sex   age                              risk  \
# 0          2020-01-12     หญิง  61.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1          2020-01-17     หญิง  74.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2          2020-01-22     หญิง  73.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3          2020-01-22      ชาย  68.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4          2020-01-24     หญิง  66.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# ...               ...      ...   ...                               ...
# 3057763    2022-03-18  ไม่ระบุ  43.0                             อื่นๆ
# 3057764    2022-03-18  ไม่ระบุ  21.0                             อื่นๆ
# 3057765    2022-03-18  ไม่ระบุ  22.0                             อื่นๆ
# 3057766    2022-03-18  ไม่ระบุ  25.0                             อื่นๆ
# 3057767    2022-03-18  ไม่ระบุ  64.0                             อื่นๆ
#
#         province_of_onset  จำนวนผู้ติดเชื้อ ภูมิศาสตร์    ชื่อจังหวัด  \
# ...

# %%
data_finish_new.isnull().any() # ดูว่าคอลัมน์ไหนมีค่า missing บ้าง จะเห็นว่าเป็น False ทั้งหมด นั่นคือไม่มีค่า missing
# Out:
# announce_date              False
# sex                        False
# age                        False
# risk                       False
# province_of_onset          False
# จำนวนผู้ติดเชื้อ           False
# ภูมิศาสตร์                 False
# ชื่อจังหวัด                False
# จำนวนประชากรชาย            False
# จำนวนประชากรหญิง           False
# จำนวนประชากรทั้งหมด        False
# จำนวนบ้าน (หลังคาเรือน)     True
# dtype: bool

# %% [markdown]
# # **แบ่งข้อมูลเพื่อนำไปใช้งาน**

# %%
data_1_y20 = data_finish_new[(data_finish_new['announce_date'] >= '2020-01-12') & (data_finish_new['announce_date'] <= '2020-12-31')]     
data_1_y20 # ข้อมูลวันที่ 12 มกราคม - 31 ธันวาคม 2020
# Out:
#      announce_date   sex   age                              risk  \
# 0       2020-01-12  หญิง  61.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1       2020-01-17  หญิง  74.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2       2020-01-22  หญิง  73.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3       2020-01-22   ชาย  68.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4       2020-01-24  หญิง  66.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# ...            ...   ...   ...                               ...
# 5234    2020-12-31   ชาย  42.0                     Cluster ระยอง
# 5235    2020-12-31  หญิง  39.0                     Cluster ระยอง
# 5236    2020-12-31   ชาย  54.0                     Cluster ระยอง
# 5237    2020-12-31   ชาย  56.0                     Cluster ระยอง
# 5238    2020-12-31   ชาย  70.0                     Cluster ระยอง
#
#      province_of_onset  จำนวนผู้ติดเชื้อ ภูมิศาสตร์    ชื่อจังหวัด  \
# 0        กรุงเทพมหานคร            572177       กลาง  กรุงเทพมหานคร
# ...

# %%
data_2_y21 = data_finish_new[(data_finish_new['announce_date'] >= '2021-01-01') & (data_finish_new['announce_date'] <= '2021-05-31')]     
data_2_y21 # ข้อมูลวันที่ 1 มกราคม - 31 พฤษภาคม 2021
# Out:
#        announce_date      sex   age                 risk province_of_onset  \
# 124       2021-03-06     หญิง  55.0  Cluster ตลาดพรพัฒน์          ปทุมธานี
# 5239      2021-01-01     หญิง  40.0    Cluster สมุทรสาคร          ปทุมธานี
# 5240      2021-01-01     หญิง  21.0        Cluster ระยอง          ปทุมธานี
# 5241      2021-01-01     หญิง  20.0          สถานบันเทิง            นครปฐม
# 5242      2021-01-01     หญิง  47.0    Cluster สมุทรสาคร            นครปฐม
# ...              ...      ...   ...                  ...               ...
# 143738    2021-05-31  ไม่ระบุ  58.0     ทัณฑสถาน/เรือนจำ           ไม่ระบุ
# 143739    2021-05-31  ไม่ระบุ  44.0     ทัณฑสถาน/เรือนจำ           ไม่ระบุ
# 143740    2021-05-31  ไม่ระบุ  36.0     ทัณฑสถาน/เรือนจำ           ไม่ระบุ
# 143741    2021-05-31  ไม่ระบุ  29.0     ทัณฑสถาน/เรือนจำ           ไม่ระบุ
# 143742    2021-05-31  ไม่ระบุ  23.0     ทัณฑสถาน/เรือนจำ           ไม่ระบุ
#
#         จำนวนผู้ติดเชื้อ ภูมิศาสตร์ ชื่อจังหวัด จำนวนประชากรชาย  \
# ...

# %%
data_3_y21 = data_finish_new[(data_finish_new['announce_date'] >= '2021-06-01') & (data_finish_new['announce_date'] <= '2021-07-31')]     
data_3_y21 # ข้อมูลวันที่ 1 มิถุนายน - 31 กรกฏาคม 2021
# Out:
#        announce_date   sex   age                                         risk  \
# 143743    2021-06-01   ชาย  38.0  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 143744    2021-06-01   ชาย  14.0                         อยู่ระหว่างการสอบสวน
# 143745    2021-06-01  หญิง  65.0                                   ระบุไม่ได้
# 143746    2021-06-01  หญิง  25.0                         อยู่ระหว่างการสอบสวน
# 143747    2021-06-01  หญิง  59.0              บุคลากรด้านการแพทย์และสาธารณสุข
# ...              ...   ...   ...                                          ...
# 543797    2021-07-31  หญิง  24.0                             ทัณฑสถาน/เรือนจำ
# 543798    2021-07-31  หญิง  35.0                             ทัณฑสถาน/เรือนจำ
# 543799    2021-07-31  หญิง  41.0                             ทัณฑสถาน/เรือนจำ
# 543800    2021-07-31  หญิง  34.0                             ทัณฑสถาน/เรือนจำ
# 543801    2021-07-31   ชาย  41.0                             ทัณฑสถาน/เรือนจำ
#
# ...

# %%
data_4_y21 = data_finish_new[(data_finish_new['announce_date'] >= '2021-07-01') & (data_finish_new['announce_date'] <= '2021-08-01')]     
data_4_y21 # ข้อมูลวันที่ 1 กรกฏาคม - 1 สิงหาคม 2021
# Out:
#        announce_date   sex   age                                         risk  \
# 236300    2021-07-01   ชาย  35.0  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 236301    2021-07-01  หญิง  41.0  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 236302    2021-07-01  หญิง  58.0  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 236303    2021-07-01   ชาย  37.0                                        อื่นๆ
# 236304    2021-07-01   ชาย  37.0                                 สถานที่ทำงาน
# ...              ...   ...   ...                                          ...
# 560141    2021-08-01   ชาย  24.0                             ทัณฑสถาน/เรือนจำ
# 560142    2021-08-01   ชาย  23.0                             ทัณฑสถาน/เรือนจำ
# 560143    2021-08-01   ชาย  44.0                             ทัณฑสถาน/เรือนจำ
# 560144    2021-08-01   ชาย  27.0                             ทัณฑสถาน/เรือนจำ
# 560145    2021-08-01   ชาย  35.0                             ทัณฑสถาน/เรือนจำ
#
# ...

# %%
data_5_y21 = data_finish_new[(data_finish_new['announce_date'] >= '2021-08-02') & (data_finish_new['announce_date'] <= '2021-08-20')]     
data_5_y21 # ข้อมูลวันที่ 2 สิงหาคม - 20 สิงหาคม 2021
# Out:
#        announce_date   sex   age              risk province_of_onset  \
# 560146    2021-08-02  หญิง  46.0             อื่นๆ              น่าน
# 560147    2021-08-02  หญิง  16.0             อื่นๆ              น่าน
# 560148    2021-08-02  หญิง   8.0             อื่นๆ              น่าน
# 560149    2021-08-02   ชาย  53.0             อื่นๆ              น่าน
# 560150    2021-08-02  หญิง  31.0             อื่นๆ              น่าน
# ...              ...   ...   ...               ...               ...
# 942933    2021-08-20   ชาย  34.0  ทัณฑสถาน/เรือนจำ           ไม่ระบุ
# 942934    2021-08-20   ชาย  60.0  ทัณฑสถาน/เรือนจำ           ไม่ระบุ
# 942935    2021-08-20   ชาย  35.0  ทัณฑสถาน/เรือนจำ           ไม่ระบุ
# 942936    2021-08-20   ชาย  20.0  ทัณฑสถาน/เรือนจำ           ไม่ระบุ
# 942937    2021-08-20   ชาย  28.0  ทัณฑสถาน/เรือนจำ           ไม่ระบุ
#
#         จำนวนผู้ติดเชื้อ ภูมิศาสตร์ ชื่อจังหวัด จำนวนประชากรชาย  \
# 560146              7238      เหนือ        น่าน        237959.0
# ...

# %%
data_6_y21 = data_finish_new[(data_finish_new['announce_date'] >= '2021-08-21') & (data_finish_new['announce_date'] <= '2021-09-20')]     
data_6_y21 # ข้อมูลวันที่ 21 สิงหาคม - 20 กันยายน 2021
# Out:
#         announce_date   sex   age  \
# 942938     2021-08-21  หญิง  79.0
# 942939     2021-08-21  หญิง  29.0
# 942940     2021-08-21  หญิง  42.0
# 942941     2021-08-21  หญิง  50.0
# 942942     2021-08-21  หญิง  16.0
# ...               ...   ...   ...
# 1389088    2021-09-20   ชาย  32.0
# 1389089    2021-09-20   ชาย  31.0
# 1389090    2021-09-20   ชาย  44.0
# 1389091    2021-09-20   ชาย  43.0
# 1389092    2021-09-20   ชาย  38.0
#
#                                                 risk province_of_onset  \
# 942938   สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้          เชียงราย
# 942939   สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้          เชียงราย
# 942940   สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้          เชียงราย
# 942941                                         อื่นๆ          เชียงราย
# 942942   สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้          เชียงราย
# ...                                              ...               ...
# ...

# %%
data_7_y21 = data_finish_new[(data_finish_new['announce_date'] >= '2021-09-21') & (data_finish_new['announce_date'] <= '2021-10-31')]     
data_7_y21 # ข้อมูลวันที่  21 กันยายน - 31 ตุลาคม 2021
# Out:
#         announce_date   sex   age  \
# 1389093    2021-09-21   ชาย  31.0
# 1389094    2021-09-21  หญิง  31.0
# 1389095    2021-09-21  หญิง  54.0
# 1389096    2021-09-21  หญิง  24.0
# 1389097    2021-09-21  หญิง  56.0
# ...               ...   ...   ...
# 1772657    2021-10-31   ชาย  33.0
# 1772658    2021-10-31   ชาย  60.0
# 1772659    2021-10-31   ชาย  24.0
# 1772660    2021-10-31  หญิง  31.0
# 1772661    2021-10-31  หญิง  24.0
#
#                                                 risk province_of_onset  \
# 1389093                                        อื่นๆ             พะเยา
# 1389094                                        อื่นๆ             พะเยา
# 1389095  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้          เชียงราย
# 1389096  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้          เชียงราย
# 1389097                         อยู่ระหว่างการสอบสวน     กรุงเทพมหานคร
# ...                                              ...               ...
# ...

# %%
data_8_y21 = data_finish_new[(data_finish_new['announce_date'] >= '2021-11-01') & (data_finish_new['announce_date'] <= '2021-12-31')]     
data_8_y21 # ข้อมูลวันที่ 1 พถศจิกายน - 31 ธันวาคม 2021
# Out:
#         announce_date   sex   age  \
# 1772662    2021-11-01  หญิง  25.0
# 1772663    2021-11-01   ชาย  28.0
# 1772664    2021-11-01   ชาย  20.0
# 1772665    2021-11-01  หญิง  33.0
# 1772666    2021-11-01  หญิง  34.0
# ...               ...   ...   ...
# 2046976    2021-12-31   ชาย  33.0
# 2046977    2021-12-31  หญิง  30.0
# 2046978    2021-12-31   ชาย  43.0
# 2046979    2021-12-31  หญิง  30.0
# 2046980    2021-12-31  หญิง  18.0
#
#                                                 risk province_of_onset  \
# 1772662                                 สถานที่ทำงาน        แม่ฮ่องสอน
# 1772663  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้        แม่ฮ่องสอน
# 1772664                                 สถานที่ทำงาน        แม่ฮ่องสอน
# 1772665                                        อื่นๆ        แม่ฮ่องสอน
# 1772666                                        อื่นๆ        แม่ฮ่องสอน
# ...                                              ...               ...
# ...

# %%
data_9_y22 = data_finish_new[(data_finish_new['announce_date'] >= '2022-01-01') & (data_finish_new['announce_date'] <= '2022-02-15')]     
data_9_y22 # ข้อมูลวันที่ 1 มกราคม - 15 กุมภาพันธ์ 2022
# Out:
#         announce_date      sex   age  \
# 2046981    2022-01-01      ชาย  39.0
# 2046982    2022-01-01     หญิง  39.0
# 2046983    2022-01-01      ชาย  64.0
# 2046984    2022-01-01      ชาย  27.0
# 2046985    2022-01-01     หญิง  35.0
# ...               ...      ...   ...
# 2418041    2022-02-15  ไม่ระบุ    76
# 2418042    2022-02-15  ไม่ระบุ    41
# 2418043    2022-02-15  ไม่ระบุ    18
# 2418044    2022-02-15  ไม่ระบุ    24
# 2418045    2022-02-15  ไม่ระบุ    60
#
#                                                 risk province_of_onset  \
# 2046981                                        อื่นๆ             พะเยา
# 2046982  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้             พะเยา
# 2046983  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้             พะเยา
# 2046984  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้             พะเยา
# 2046985                         อยู่ระหว่างการสอบสวน             พะเยา
# ...                                              ...               ...
# ...

# %%
data_10_y22 = data_finish_new[(data_finish_new['announce_date'] >= '2022-02-16') & (data_finish_new['announce_date'] <= '2022-03-01')]     
data_10_y22 # ข้อมูลวันที่ 16 กุมภาพันธ์ - 1 มีนาคม 2022
# Out:
#         announce_date      sex   age  \
# 2418046    2022-02-16      ชาย    28
# 2418047    2022-02-16     หญิง    73
# 2418048    2022-02-16     หญิง    10
# 2418049    2022-02-16     หญิง    41
# 2418050    2022-02-16     หญิง    51
# ...               ...      ...   ...
# 2689424    2022-03-01  ไม่ระบุ  47.0
# 2689425    2022-03-01      ชาย  42.0
# 2689426    2022-03-01     หญิง  23.0
# 2689427    2022-03-01      ชาย  61.0
# 2689428    2022-03-01     หญิง  30.0
#
#                                                 risk province_of_onset  \
# 2418046              บุคลากรด้านการแพทย์และสาธารณสุข             พะเยา
# 2418047  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้             พะเยา
# 2418048  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้             พะเยา
# 2418049  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้             พะเยา
# 2418050                                        อื่นๆ             พะเยา
# ...                                              ...               ...
# ...

# %%
data_11_y22 = data_finish_new[(data_finish_new['announce_date'] >= '2022-03-02') & (data_finish_new['announce_date'] <= '2022-03-18')]     
data_11_y22 # ข้อมูลวันที่ 2 มีนาคม - 18 มีนาคม  2022
# Out:
#         announce_date      sex   age   risk province_of_onset  \
# 2689429    2022-03-02      ชาย  34.0  อื่นๆ           ไม่ระบุ
# 2689430    2022-03-02      ชาย  29.0  อื่นๆ           ไม่ระบุ
# 2689431    2022-03-02      ชาย  26.0  อื่นๆ           ไม่ระบุ
# 2689432    2022-03-02     หญิง  64.0  อื่นๆ           ไม่ระบุ
# 2689433    2022-03-02     หญิง  40.0  อื่นๆ           ไม่ระบุ
# ...               ...      ...   ...    ...               ...
# 3057763    2022-03-18  ไม่ระบุ  43.0  อื่นๆ           ไม่ระบุ
# 3057764    2022-03-18  ไม่ระบุ  21.0  อื่นๆ     กรุงเทพมหานคร
# 3057765    2022-03-18  ไม่ระบุ  22.0  อื่นๆ     กรุงเทพมหานคร
# 3057766    2022-03-18  ไม่ระบุ  25.0  อื่นๆ     กรุงเทพมหานคร
# 3057767    2022-03-18  ไม่ระบุ  64.0  อื่นๆ         กำแพงเพชร
#
#          จำนวนผู้ติดเชื้อ ภูมิศาสตร์    ชื่อจังหวัด จำนวนประชากรชาย  \
# 2689429            400249    ไม่ระบุ        ไม่ระบุ         ไม่ระบุ
# 2689430            400249    ไม่ระบุ        ไม่ระบุ         ไม่ระบุ
# ...

# %%
data_12_y22 = data_finish_new[(data_finish_new['announce_date'] >= '2022-03-01') & (data_finish_new['announce_date'] <= '2022-03-18')]     
data_12_y22 # ข้อมูลวันที่ 1 มีนาคม - 18 มีนาคม  2022
# Out:
#         announce_date      sex   age  \
# 2670578    2022-03-01     หญิง  47.0
# 2670579    2022-03-01     หญิง  34.0
# 2670580    2022-03-01     หญิง  11.0
# 2670581    2022-03-01     หญิง  20.0
# 2670582    2022-03-01     หญิง  16.0
# ...               ...      ...   ...
# 3057763    2022-03-18  ไม่ระบุ  43.0
# 3057764    2022-03-18  ไม่ระบุ  21.0
# 3057765    2022-03-18  ไม่ระบุ  22.0
# 3057766    2022-03-18  ไม่ระบุ  25.0
# 3057767    2022-03-18  ไม่ระบุ  64.0
#
#                                                 risk province_of_onset  \
# 2670578                                        อื่นๆ           สุโขทัย
# 2670579                                        อื่นๆ           สุโขทัย
# 2670580                                        อื่นๆ           สุโขทัย
# 2670581  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้           สุโขทัย
# 2670582                                        อื่นๆ           สุโขทัย
# ...                                              ...               ...
# ...

# %% [markdown]
# # **นำข้อมูลออกมาใช้งาน**

# %%
data_1_y20.to_csv(os.path.join(path,'data_1_2020.csv')) #แบ่งเป็น 12 มกราคม - 31 ธันวาคม 2020

# %%
data_2_y21.to_csv(os.path.join(path,'data_1_5_2021.csv')) # แบ่งเป็นเดือน 1 มกราคม - 31 พฤษภาคม 2021

# %%
data_3_y21.to_csv(os.path.join(path,'data_6_7_2021.csv')) # แบ่งเป็นเดือน 1 มิถุนายน - 31 กรกฏาคม 2021

# %%
data_4_y21.to_csv(os.path.join(path,'data_7_8_2021.csv')) # แบ่งเป็นเดือน 1 กรกฏาคม - 1 สิงหาคม 2021

# %%
data_5_y21.to_csv(os.path.join(path,'data_8_8_2022.csv')) # แบ่งเป็นเดือน 2 สิงหาคม - 20 สิงหาคม 2021

# %%
data_6_y21.to_csv(os.path.join(path,'data_8_9_2021.csv')) # แบ่งเป็นเดือน 21 สิงหาคม - 20 กันยายน 2021

# %%
data_7_y21.to_csv(os.path.join(path,'data_9_10_2021.csv')) # แบ่งเป็นเดือน 21 กันยายน - 31 ตุลาคม 2021

# %%
data_8_y21.to_csv(os.path.join(path,'data_11_12_2021.csv')) # แบ่งเป็นเดือน 1 พถศจิกายน - 31 ธันวาคม 2021

# %%
data_9_y22.to_csv(os.path.join(path,'data_1_2_2022.csv')) # แบ่งเป็นเดือน 1 มกราคม - 15 กุมภาพันธ์ 2022

# %%
data_10_y22.to_csv(os.path.join(path,'data_2_3_2022.csv')) # แบ่งเป็นเดือน 16 กุมภาพันธ์ - 1 มีนาคม 2022

# %%
data_11_y22.to_csv(os.path.join(path,'data_2_3_3_2022.csv')) # แบ่งเป็นเดือน 2 มีนาคม - 18 มีนาคม  2022

# %%
data_12_y22.to_csv(os.path.join(path,'data_2_3_3_2022.csv')) # แบ่งเป็นเดือน 1 มีนาคม - 18 มีนาคม  2022

# %% [markdown]
# # **Finish :)**
